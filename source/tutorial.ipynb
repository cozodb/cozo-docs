# %% [markdown]
# # Tutorial
#
# This tutorial will teach you the basics of using the Cozo database.
#
# There are several ways you can run the queries in this tutorial:
#
# * You can run the examples in your browser without installing anything: just open [Cozo in Wasm](https://www.cozodb.org/wasm-demo/)
# and you are ready to go.
# * You can download the appropriate `cozo-*` executable for your operating system from the [release page](https://github.com/cozodb/cozo/releases), uncompress, rename to `cozo`, and run the REPL mode by running in a terminal `cozo repl` and follow along.
# * If you are familiar with the Python datascience stack, you should following the instruction [here](https://github.com/cozodb/pycozo) instead to run this notebook in Jupyter Lab, with the [notebook file](https://github.com/cozodb/cozo-docs/blob/main/source/tutorial.ipynb).
# * There are [many other ways](https://github.com/cozodb/cozo#Install), but the above ones are the easiest.
#
# The following cell is to set up Jupyter. Ignore if you are using other methods.

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %load_ext pycozo.ipyext_direct

# %% [markdown]
# ## Introduction
#
# Datalog is pattern matching for your data.
#
# This sort of thing (Ruby):
#
# ```
# config = {db: {user: 'admin', password: 'abc123'}}
#
# case config
# in db: {user:} # matches subhash and puts matched value in variable user
#   puts "Connect with user '#{user}'"
# in connection: {username: }
#   puts "Connect with user '#{username}'"
# else
#   puts "Unrecognized structure of config"
# end
# # Prints: "Connect with user 'admin'"
# ```
# Broadly speaking, you provide some values and variables that constitute a pattern for pulling apart some data structure. The matching simultaneously chooses an execution path and gets values of the variables that match out of the data structure.
#
# ## First steps
#
# Cozo is a relational database. Relations are similar to tables in SQL. The difference is that you can't have duplicate rows in a relation.
#
# You can define and then retrieve all the rows from a relation in Cozo like this:

# %%
?[] <- [['hello', 'world', 'Cozo!']]
# Out:
# <style type="text/css">
# #T_b9137_row0_col0, #T_b9137_row0_col1, #T_b9137_row0_col2 {
#   color: black;
# }
# </style>
# <table id="T_b9137">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b9137_level0_col0" class="col_heading level0 col0" >_0</th>
#       <th id="T_b9137_level0_col1" class="col_heading level0 col1" >_1</th>
#       <th id="T_b9137_level0_col2" class="col_heading level0 col2" >_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b9137_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b9137_row0_col0" class="data row0 col0" >hello</td>
#       <td id="T_b9137_row0_col1" class="data row0 col1" >world</td>
#       <td id="T_b9137_row0_col2" class="data row0 col2" >Cozo!</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This is a _rule_. The <- separates the _head_ of the rule on the left from the _body_ on the right. The `[] <-` acts like `SELECT *` in SQL. The above query in SQL would look something like:
#
# ```
# SELECT * FROM (VALUES(‘hello’, ‘world’, ‘sql’)) as unnecessary_alias;
# ```
#
# (a hint here of Datalog’s freedom from the endless ceremony that plagues SQL)
#
# You can have multiple rows:

# %%
?[] <- [[1, 2, 3], ['a', 'b', 'c']]
# Out:
# <style type="text/css">
# #T_a184a_row0_col0, #T_a184a_row0_col1, #T_a184a_row0_col2 {
#   color: #307fc1;
# }
# #T_a184a_row1_col0, #T_a184a_row1_col1, #T_a184a_row1_col2 {
#   color: black;
# }
# </style>
# <table id="T_a184a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a184a_level0_col0" class="col_heading level0 col0" >_0</th>
#       <th id="T_a184a_level0_col1" class="col_heading level0 col1" >_1</th>
#       <th id="T_a184a_level0_col2" class="col_heading level0 col2" >_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a184a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a184a_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a184a_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_a184a_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_a184a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a184a_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_a184a_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_a184a_row1_col2" class="data row1 col2" >c</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can have the usual sorts of types:

# %%
?[] <- [[1.5, 2.5, 3, 4, 5.5], 
        ['aA', 'bB', 'cC', 'dD', 'eE'], 
        [true, false, null, -1.4e-2, "A string with double quotes"]]
# Out:
# <style type="text/css">
# #T_790af_row0_col0, #T_790af_row0_col1, #T_790af_row0_col3, #T_790af_row1_col0, #T_790af_row1_col1, #T_790af_row1_col2, #T_790af_row1_col3, #T_790af_row1_col4 {
#   color: #307fc1;
# }
# #T_790af_row0_col2 {
#   color: #bf5b3d;
# }
# #T_790af_row0_col4, #T_790af_row2_col0, #T_790af_row2_col1, #T_790af_row2_col2, #T_790af_row2_col3, #T_790af_row2_col4 {
#   color: black;
# }
# </style>
# <table id="T_790af">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_790af_level0_col0" class="col_heading level0 col0" >_0</th>
#       <th id="T_790af_level0_col1" class="col_heading level0 col1" >_1</th>
#       <th id="T_790af_level0_col2" class="col_heading level0 col2" >_2</th>
#       <th id="T_790af_level0_col3" class="col_heading level0 col3" >_3</th>
#       <th id="T_790af_level0_col4" class="col_heading level0 col4" >_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_790af_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_790af_row0_col0" class="data row0 col0" >True</td>
#       <td id="T_790af_row0_col1" class="data row0 col1" >False</td>
#       <td id="T_790af_row0_col2" class="data row0 col2" >None</td>
#       <td id="T_790af_row0_col3" class="data row0 col3" >-0.014000</td>
#       <td id="T_790af_row0_col4" class="data row0 col4" >A string with double quotes</td>
#     </tr>
#     <tr>
#       <th id="T_790af_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_790af_row1_col0" class="data row1 col0" >1.500000</td>
#       <td id="T_790af_row1_col1" class="data row1 col1" >2.500000</td>
#       <td id="T_790af_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_790af_row1_col3" class="data row1 col3" >4</td>
#       <td id="T_790af_row1_col4" class="data row1 col4" >5.500000</td>
#     </tr>
#     <tr>
#       <th id="T_790af_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_790af_row2_col0" class="data row2 col0" >aA</td>
#       <td id="T_790af_row2_col1" class="data row2 col1" >bB</td>
#       <td id="T_790af_row2_col2" class="data row2 col2" >cC</td>
#       <td id="T_790af_row2_col3" class="data row2 col3" >dD</td>
#       <td id="T_790af_row2_col4" class="data row2 col4" >eE</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The input literal representations are similar to those in JavaScript.
# In particular, strings in double quotes are guaranteed to be interpreted in the same way as in JSON.
# The output are in JSON, but how they appear on your screen depends on your setup.
# For example, if you are using a Python setup, booleans are displayed as `True` and `False` instead of in lowercase,
# since they are converted to the native Python datatypes for display.
#
# In the last example, you may have noticed that the returned order is not the same as the input order.
# This is because in Cozo relations are always stored as trees, and trees are always sorted.
#
# Another consequence of relations as trees is that you can have no duplicate rows:

# %%
?[] <- [[1], [2], [1], [2], [1]]
# Out:
# <style type="text/css">
# #T_4a6a5_row0_col0, #T_4a6a5_row1_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_4a6a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4a6a5_level0_col0" class="col_heading level0 col0" >_0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4a6a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4a6a5_row0_col0" class="data row0 col0" >1</td>
#     </tr>
#     <tr>
#       <th id="T_4a6a5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4a6a5_row1_col0" class="data row1 col0" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Expressions
#
# The next example shows the use of various functions, expressions and comments:

# %%
?[] <- [[
            1 + 2, # addition
            3 / 4, # division
            5 == 6, # equality
            7 > 8, # greater
            true || false, # or
            false && true, # and
            lowercase('HELLO'), # function
            rand_float(), # function taking no argument
            union([1, 2, 3], [3, 4, 5], [5, 6, 7]), # variadic function
        ]]
# Out:
# <style type="text/css">
# #T_68897_row0_col0, #T_68897_row0_col1, #T_68897_row0_col2, #T_68897_row0_col3, #T_68897_row0_col4, #T_68897_row0_col5, #T_68897_row0_col7 {
#   color: #307fc1;
# }
# #T_68897_row0_col6 {
#   color: black;
# }
# #T_68897_row0_col8 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_68897">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68897_level0_col0" class="col_heading level0 col0" >_0</th>
#       <th id="T_68897_level0_col1" class="col_heading level0 col1" >_1</th>
#       <th id="T_68897_level0_col2" class="col_heading level0 col2" >_2</th>
#       <th id="T_68897_level0_col3" class="col_heading level0 col3" >_3</th>
#       <th id="T_68897_level0_col4" class="col_heading level0 col4" >_4</th>
#       <th id="T_68897_level0_col5" class="col_heading level0 col5" >_5</th>
#       <th id="T_68897_level0_col6" class="col_heading level0 col6" >_6</th>
#       <th id="T_68897_level0_col7" class="col_heading level0 col7" >_7</th>
#       <th id="T_68897_level0_col8" class="col_heading level0 col8" >_8</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68897_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68897_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_68897_row0_col1" class="data row0 col1" >0.750000</td>
#       <td id="T_68897_row0_col2" class="data row0 col2" >False</td>
#       <td id="T_68897_row0_col3" class="data row0 col3" >False</td>
#       <td id="T_68897_row0_col4" class="data row0 col4" >True</td>
#       <td id="T_68897_row0_col5" class="data row0 col5" >False</td>
#       <td id="T_68897_row0_col6" class="data row0 col6" >hello</td>
#       <td id="T_68897_row0_col7" class="data row0 col7" >0.061268</td>
#       <td id="T_68897_row0_col8" class="data row0 col8" >[1, 2, 3, 4, 5, 6, 7]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Cozo has a pretty robust set of [built-in functions and operators](functions.rst).
#
# ## Find values for these variables
#
# More complex queries proceed by providing some expressions with values and variables, much like pattern matching in your favourite language.
#
# Cozo tries to find all the sets of rows that match the given values, including values for the variables that also match across all the expressions. Some examples will make this clearer.

# %%
?[first, second, third] <- [[1, 2, 3], ['a', 'b', 'c']]
# Out:
# <style type="text/css">
# #T_3a398_row0_col0, #T_3a398_row0_col1, #T_3a398_row0_col2 {
#   color: #307fc1;
# }
# #T_3a398_row1_col0, #T_3a398_row1_col1, #T_3a398_row1_col2 {
#   color: black;
# }
# </style>
# <table id="T_3a398">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3a398_level0_col0" class="col_heading level0 col0" >first</th>
#       <th id="T_3a398_level0_col1" class="col_heading level0 col1" >second</th>
#       <th id="T_3a398_level0_col2" class="col_heading level0 col2" >third</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3a398_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3a398_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_3a398_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_3a398_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_3a398_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3a398_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_3a398_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_3a398_row1_col2" class="data row1 col2" >c</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here, we’ve just provided named variables for the values coming back.
#
# Note that you have to do obvious things, like not having different numbers of columns within one relation. Typing can be strict or loose as you choose (so far, it’s all been loose; we’ll see examples of strict typing shortly).
#
# For `<-` (called _constant_) rules, the number of bindings must match the actual data (the _arity_), otherwise, you will get an error:

# %%
?[first, second] <- [[1, 2, 3], ['a', 'b', 'c']]
# Out:
# parser::fixed_rule_head_arity_mismatch
#
#   × Fixed rule head arity mismatch
#    ╭─[1:1]
#  1 │ ?[first, second] <- [[1, 2, 3], ['a', 'b', 'c']]
#    · ─────────────────────────────────────────────────
#  2 │
#    ╰────
#   help: Expected arity: 3, number of arguments given: 2

# %% [markdown]
# Now let's define rules that _apply_ (use) other rules:

# %%
rule[first, second, third] <- [[1, 2, 3], ['a', 'b', 'c']]
?[a, b, c] := rule[a, b, c]
# Out:
# <style type="text/css">
# #T_72bdd_row0_col0, #T_72bdd_row0_col1, #T_72bdd_row0_col2 {
#   color: #307fc1;
# }
# #T_72bdd_row1_col0, #T_72bdd_row1_col1, #T_72bdd_row1_col2 {
#   color: black;
# }
# </style>
# <table id="T_72bdd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72bdd_level0_col0" class="col_heading level0 col0" >a</th>
#       <th id="T_72bdd_level0_col1" class="col_heading level0 col1" >b</th>
#       <th id="T_72bdd_level0_col2" class="col_heading level0 col2" >c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72bdd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72bdd_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_72bdd_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_72bdd_row0_col2" class="data row0 col2" >3</td>
#     </tr>
#     <tr>
#       <th id="T_72bdd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72bdd_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_72bdd_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_72bdd_row1_col2" class="data row1 col2" >c</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You’ll notice the two different connectors. The first, `<-`, is actually syntactic sugar for `<~`, which is used for invoking functions on the right hand side (as well as Cozo's many built-in functions, you can write your own in the host language). `<-` is invoking a Constant function that looks like `rule[first, second, third] <~ Constant(data: [[1, 2, 3], ['a', 'b', 'c']])` `<-` and `<~` rules are called _constant rules_.
#
# The second rule is an _inline_ rule, meaning it’s not invoking anything external to the database; it’s just matching data. Note that because it is named `?`, it is the _result_ of the query.
#
# Note how in the second line, we match a, b, c to the first, second, third in the first rule.
#
# We don’t have to use all the variables from the body in an inline rule:

# %%
rule[first, second, third] <- [[1, 2, 3], ['a', 'b', 'c']]
?[c, b] := rule[a, b, c]
# Out:
# <style type="text/css">
# #T_13cd0_row0_col0, #T_13cd0_row0_col1 {
#   color: #307fc1;
# }
# #T_13cd0_row1_col0, #T_13cd0_row1_col1 {
#   color: black;
# }
# </style>
# <table id="T_13cd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13cd0_level0_col0" class="col_heading level0 col0" >c</th>
#       <th id="T_13cd0_level0_col1" class="col_heading level0 col1" >b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13cd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13cd0_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_13cd0_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_13cd0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13cd0_row1_col0" class="data row1 col0" >c</td>
#       <td id="T_13cd0_row1_col1" class="data row1 col1" >b</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's get a bit fancier:

# %%
?[c, b] := rule[a, b, c], is_num(a)
rule[first, second, third] <- [[1, 2, 3], ['a', 'b', 'c']]
# Out:
# <style type="text/css">
# #T_6f25b_row0_col0, #T_6f25b_row0_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_6f25b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6f25b_level0_col0" class="col_heading level0 col0" >c</th>
#       <th id="T_6f25b_level0_col1" class="col_heading level0 col1" >b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6f25b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6f25b_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_6f25b_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here, the first rule had multiple bodies, separated by commas. These are effectively joined by _and_. We see here how the variable `a` matches with a value from the database, but _also_ has to return _true_ when passed to the _is_num_ function.
#
# You can also bind constants to rule applications directly:

# %%
rule[first, second, third] <- [[1, 2, 3], ['a', 'b', 'c']]
?[c, b] := rule['a', b, c]
# Out:
# <style type="text/css">
# #T_c6b47_row0_col0, #T_c6b47_row0_col1 {
#   color: black;
# }
# </style>
# <table id="T_c6b47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6b47_level0_col0" class="col_heading level0 col0" >c</th>
#       <th id="T_c6b47_level0_col1" class="col_heading level0 col1" >b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6b47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6b47_row0_col0" class="data row0 col0" >c</td>
#       <td id="T_c6b47_row0_col1" class="data row0 col1" >b</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The pattern in the head on the second line matches only rows with an 'a' for the first field value.
#
# You can have multiple rules with the same _head_ name, which is like joining their bodies with `OR`.

# %% [markdown]
# ```
# important[a] := recent[a], unread[a], not deleted[a]
# important[a] := flagged[a], not deleted[a]
# ```
#
# This means _a_ is important if it isn’t deleted, and it’s either flagged, or recent and unread. You can also use 'and', 'or', 'not' and parentheses, although the style above is more idiomatic.

# %% [markdown]
# We can just directly set a value as part of the query, using '=':

# %%
rule[first, second, third] <- [[1, 2, 3], ['a', 'b', 'c']]
?[c, b, d] := rule[a, b, c], is_num(a), d = a + b + 2*c
# Out:
# <style type="text/css">
# #T_cb721_row0_col0, #T_cb721_row0_col1, #T_cb721_row0_col2 {
#   color: #307fc1;
# }
# </style>
# <table id="T_cb721">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cb721_level0_col0" class="col_heading level0 col0" >c</th>
#       <th id="T_cb721_level0_col1" class="col_heading level0 col1" >b</th>
#       <th id="T_cb721_level0_col2" class="col_heading level0 col2" >d</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cb721_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cb721_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_cb721_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_cb721_row0_col2" class="data row0 col2" >9</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The unification `=` unifies with a single value. Use `in` to unify with each value within a list in turn:

# %%
?[x, y] := x in [1, 2, 3], y in ['x', 'y']
# Out:
# <style type="text/css">
# #T_0b186_row0_col0, #T_0b186_row1_col0, #T_0b186_row2_col0, #T_0b186_row3_col0, #T_0b186_row4_col0, #T_0b186_row5_col0 {
#   color: #307fc1;
# }
# #T_0b186_row0_col1, #T_0b186_row1_col1, #T_0b186_row2_col1, #T_0b186_row3_col1, #T_0b186_row4_col1, #T_0b186_row5_col1 {
#   color: black;
# }
# </style>
# <table id="T_0b186">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b186_level0_col0" class="col_heading level0 col0" >x</th>
#       <th id="T_0b186_level0_col1" class="col_heading level0 col1" >y</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b186_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b186_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0b186_row0_col1" class="data row0 col1" >x</td>
#     </tr>
#     <tr>
#       <th id="T_0b186_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0b186_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_0b186_row1_col1" class="data row1 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_0b186_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0b186_row2_col0" class="data row2 col0" >2</td>
#       <td id="T_0b186_row2_col1" class="data row2 col1" >x</td>
#     </tr>
#     <tr>
#       <th id="T_0b186_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0b186_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_0b186_row3_col1" class="data row3 col1" >y</td>
#     </tr>
#     <tr>
#       <th id="T_0b186_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0b186_row4_col0" class="data row4 col0" >3</td>
#       <td id="T_0b186_row4_col1" class="data row4 col1" >x</td>
#     </tr>
#     <tr>
#       <th id="T_0b186_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0b186_row5_col0" class="data row5 col0" >3</td>
#       <td id="T_0b186_row5_col1" class="data row5 col1" >y</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Having multiple rule applications in the body generates every combination of the bindings:

# %%
r1[] <- [[1, 'a'], [2, 'b']]
r2[] <- [[2, 'B'], [3, 'C']]

?[l1, l2] := r1[a, l1], 
             r2[b, l2]
# Out:
# <style type="text/css">
# #T_fd539_row0_col0, #T_fd539_row0_col1, #T_fd539_row1_col0, #T_fd539_row1_col1, #T_fd539_row2_col0, #T_fd539_row2_col1, #T_fd539_row3_col0, #T_fd539_row3_col1 {
#   color: black;
# }
# </style>
# <table id="T_fd539">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd539_level0_col0" class="col_heading level0 col0" >l1</th>
#       <th id="T_fd539_level0_col1" class="col_heading level0 col1" >l2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd539_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd539_row0_col0" class="data row0 col0" >a</td>
#       <td id="T_fd539_row0_col1" class="data row0 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_fd539_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd539_row1_col0" class="data row1 col0" >a</td>
#       <td id="T_fd539_row1_col1" class="data row1 col1" >C</td>
#     </tr>
#     <tr>
#       <th id="T_fd539_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd539_row2_col0" class="data row2 col0" >b</td>
#       <td id="T_fd539_row2_col1" class="data row2 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_fd539_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd539_row3_col0" class="data row3 col0" >b</td>
#       <td id="T_fd539_row3_col1" class="data row3 col1" >C</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This is a cross join in SQL
#
# We’ve now seen enough of the basics to start looking at some more complex operations.
#
# ## Joins, made easy

# %%
r1[] <- [[1, 'a'], [2, 'b']]
r2[] <- [[2, 'B'], [3, 'C']]

?[l1, l2] := r1[a, l1], 
             r2[a, l2] # reused `a`
# Out:
# <style type="text/css">
# #T_c6288_row0_col0, #T_c6288_row0_col1 {
#   color: black;
# }
# </style>
# <table id="T_c6288">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6288_level0_col0" class="col_heading level0 col0" >l1</th>
#       <th id="T_c6288_level0_col1" class="col_heading level0 col1" >l2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6288_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6288_row0_col0" class="data row0 col0" >b</td>
#       <td id="T_c6288_row0_col1" class="data row0 col1" >B</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# A join is as simple as using the same variable in different relations. Here, we are asking for a single value of `a` that matches a row in each of the sources at the same time.
#
# Compare the above with the SQL for the same operation:
#
# ```
# WITH
# 	r1 AS SELECT * FROM (VALUES (1, ‘a’), (2, ‘b’)) as t(c1, c2),
# 	r2 AS SELECT * FROM (VALUES(2, ‘B’), (3, ‘C’)) as u(d1, d2)
# SELECT
# 	r1.c2, r2.d2 FROM r1 JOIN r2 ON (r1.c1 = r2.d1);
# ```
#
# An outer join is done by considering the cases separately:

# %%
a[x, y] <- [[1, 2], [3, 4]]
b[y, z] <- [[2, 3], [2, 4]]
?[x, y, z] := a[x, y], b[y, z]
?[x, y, z] := a[x, y], not b[y, _], z = null
# Out:
# <style type="text/css">
# #T_a5094_row0_col0, #T_a5094_row0_col1, #T_a5094_row0_col2, #T_a5094_row1_col0, #T_a5094_row1_col1, #T_a5094_row1_col2, #T_a5094_row2_col0, #T_a5094_row2_col1, #T_a5094_row2_col2 {
#   color: #307fc1;
# }
# </style>
# <table id="T_a5094">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a5094_level0_col0" class="col_heading level0 col0" >x</th>
#       <th id="T_a5094_level0_col1" class="col_heading level0 col1" >y</th>
#       <th id="T_a5094_level0_col2" class="col_heading level0 col2" >z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a5094_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a5094_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_a5094_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_a5094_row0_col2" class="data row0 col2" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5094_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a5094_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_a5094_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_a5094_row1_col2" class="data row1 col2" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a5094_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a5094_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_a5094_row2_col1" class="data row2 col1" >4</td>
#       <td id="T_a5094_row2_col2" class="data row2 col2" >nan</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note that we still only have a single output `?` rule here; it is split into two parts effectively joining the right sides with `or` as we discussed previously.

# %% [markdown]
# ## Stored relations
#
# The relations we've seen so far were created on the fly as constant rules, and only persist for the duration of the query.
#
# You can of course also persist data. To do this, you first declare the relation:

# %%
:create stored {c1, c2}
# Out:
# <style type="text/css">
# #T_c567d_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_c567d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c567d_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c567d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c567d_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This creates a relation called 'stored' with two columns that will take any type. Here is a fully typed relation:

# %%
:create dept_info {
    company_name: String,
    department_name: String,
    =>
    head_count: Int default 0,
    address: String,
}
# Out:
# <style type="text/css">
# #T_030e5_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_030e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_030e5_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_030e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_030e5_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This should be fairly obvious, except for the `=>` in the middle. This symbol separates the columns in the primary key before the `=>` from the other columns. If the `=>` isn’t present, all of the columns are considered part of the primary key.

# %%
?[a, b, c] <- [[1, 'a', 'A'],
[2, 'b', 'B'],
[3, 'c', 'C'],
[4, 'd', 'D']]

:create fd {a, b => c}
# Out:
# <style type="text/css">
# #T_e31fd_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_e31fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e31fd_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e31fd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e31fd_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %%
?[a, b, c] := *fd[a, b, c]
# Out:
# <style type="text/css">
# #T_7d037_row0_col0, #T_7d037_row1_col0, #T_7d037_row2_col0, #T_7d037_row3_col0 {
#   color: #307fc1;
# }
# #T_7d037_row0_col1, #T_7d037_row0_col2, #T_7d037_row1_col1, #T_7d037_row1_col2, #T_7d037_row2_col1, #T_7d037_row2_col2, #T_7d037_row3_col1, #T_7d037_row3_col2 {
#   color: black;
# }
# </style>
# <table id="T_7d037">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d037_level0_col0" class="col_heading level0 col0" >a</th>
#       <th id="T_7d037_level0_col1" class="col_heading level0 col1" >b</th>
#       <th id="T_7d037_level0_col2" class="col_heading level0 col2" >c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d037_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d037_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_7d037_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_7d037_row0_col2" class="data row0 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_7d037_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7d037_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_7d037_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_7d037_row1_col2" class="data row1 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_7d037_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7d037_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_7d037_row2_col1" class="data row2 col1" >c</td>
#       <td id="T_7d037_row2_col2" class="data row2 col2" >C</td>
#     </tr>
#     <tr>
#       <th id="T_7d037_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7d037_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_7d037_row3_col1" class="data row3 col1" >d</td>
#       <td id="T_7d037_row3_col2" class="data row3 col2" >D</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note how we create rows in fd as we define it.
#
# In Cozo terms, the fields _after_ the => are _functionally dependent_ on the ones before. Those before determine identity, which lets the :put operation function as (_upsert_)[https://wiki.postgresql.org/wiki/UPSERT](update-or-insert).

# %%
?[a, b, c] <- [[3, 'c', 'CCCCCCC']]

:put fd {a, b => c}
# Out:
# <style type="text/css">
# #T_e359c_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_e359c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e359c_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e359c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e359c_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %%
?[a, b, c] := *fd[a, b, c]
# Out:
# <style type="text/css">
# #T_0a060_row0_col0, #T_0a060_row1_col0, #T_0a060_row2_col0, #T_0a060_row3_col0 {
#   color: #307fc1;
# }
# #T_0a060_row0_col1, #T_0a060_row0_col2, #T_0a060_row1_col1, #T_0a060_row1_col2, #T_0a060_row2_col1, #T_0a060_row2_col2, #T_0a060_row3_col1, #T_0a060_row3_col2 {
#   color: black;
# }
# </style>
# <table id="T_0a060">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0a060_level0_col0" class="col_heading level0 col0" >a</th>
#       <th id="T_0a060_level0_col1" class="col_heading level0 col1" >b</th>
#       <th id="T_0a060_level0_col2" class="col_heading level0 col2" >c</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a060_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0a060_row0_col0" class="data row0 col0" >1</td>
#       <td id="T_0a060_row0_col1" class="data row0 col1" >a</td>
#       <td id="T_0a060_row0_col2" class="data row0 col2" >A</td>
#     </tr>
#     <tr>
#       <th id="T_0a060_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0a060_row1_col0" class="data row1 col0" >2</td>
#       <td id="T_0a060_row1_col1" class="data row1 col1" >b</td>
#       <td id="T_0a060_row1_col2" class="data row1 col2" >B</td>
#     </tr>
#     <tr>
#       <th id="T_0a060_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0a060_row2_col0" class="data row2 col0" >3</td>
#       <td id="T_0a060_row2_col1" class="data row2 col1" >c</td>
#       <td id="T_0a060_row2_col2" class="data row2 col2" >CCCCCCC</td>
#     </tr>
#     <tr>
#       <th id="T_0a060_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0a060_row3_col0" class="data row3 col0" >4</td>
#       <td id="T_0a060_row3_col1" class="data row3 col1" >d</td>
#       <td id="T_0a060_row3_col2" class="data row3 col2" >D</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note that the name of the stored relation should not start with an underscore `_`. You will get no error if you use a name starting with an underscore, but you will discover that the relation won't be persisted. What you are dealing with is actually what is called an [_ephemeral relation_](stored.rst).
#
# You can see the stored relations in your system by running a _system op_:

# %%
::relations
# Out:
# <style type="text/css">
# #T_0c7d8_row0_col0, #T_0c7d8_row0_col2, #T_0c7d8_row0_col8, #T_0c7d8_row1_col0, #T_0c7d8_row1_col2, #T_0c7d8_row1_col8, #T_0c7d8_row2_col0, #T_0c7d8_row2_col2, #T_0c7d8_row2_col8 {
#   color: black;
# }
# #T_0c7d8_row0_col1, #T_0c7d8_row0_col3, #T_0c7d8_row0_col4, #T_0c7d8_row0_col5, #T_0c7d8_row0_col6, #T_0c7d8_row0_col7, #T_0c7d8_row1_col1, #T_0c7d8_row1_col3, #T_0c7d8_row1_col4, #T_0c7d8_row1_col5, #T_0c7d8_row1_col6, #T_0c7d8_row1_col7, #T_0c7d8_row2_col1, #T_0c7d8_row2_col3, #T_0c7d8_row2_col4, #T_0c7d8_row2_col5, #T_0c7d8_row2_col6, #T_0c7d8_row2_col7 {
#   color: #307fc1;
# }
# </style>
# <table id="T_0c7d8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0c7d8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_0c7d8_level0_col1" class="col_heading level0 col1" >arity</th>
#       <th id="T_0c7d8_level0_col2" class="col_heading level0 col2" >access_level</th>
#       <th id="T_0c7d8_level0_col3" class="col_heading level0 col3" >n_keys</th>
#       <th id="T_0c7d8_level0_col4" class="col_heading level0 col4" >n_non_keys</th>
#       <th id="T_0c7d8_level0_col5" class="col_heading level0 col5" >n_put_triggers</th>
#       <th id="T_0c7d8_level0_col6" class="col_heading level0 col6" >n_rm_triggers</th>
#       <th id="T_0c7d8_level0_col7" class="col_heading level0 col7" >n_replace_triggers</th>
#       <th id="T_0c7d8_level0_col8" class="col_heading level0 col8" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0c7d8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0c7d8_row0_col0" class="data row0 col0" >dept_info</td>
#       <td id="T_0c7d8_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_0c7d8_row0_col2" class="data row0 col2" >normal</td>
#       <td id="T_0c7d8_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_0c7d8_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_0c7d8_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_0c7d8_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_0c7d8_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_0c7d8_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_0c7d8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0c7d8_row1_col0" class="data row1 col0" >fd</td>
#       <td id="T_0c7d8_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_0c7d8_row1_col2" class="data row1 col2" >normal</td>
#       <td id="T_0c7d8_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_0c7d8_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_0c7d8_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_0c7d8_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_0c7d8_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_0c7d8_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_0c7d8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0c7d8_row2_col0" class="data row2 col0" >stored</td>
#       <td id="T_0c7d8_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_0c7d8_row2_col2" class="data row2 col2" >normal</td>
#       <td id="T_0c7d8_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_0c7d8_row2_col4" class="data row2 col4" >0</td>
#       <td id="T_0c7d8_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_0c7d8_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_0c7d8_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_0c7d8_row2_col8" class="data row2 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Note that we have regular operations like `:create` that start with a :, and system operations with a ::.
#
# We can investigate the columns of the stored relation:

# %%
::columns stored
# Out:
# <style type="text/css">
# #T_35fa7_row0_col0, #T_35fa7_row0_col3, #T_35fa7_row1_col0, #T_35fa7_row1_col3 {
#   color: black;
# }
# #T_35fa7_row0_col1, #T_35fa7_row0_col2, #T_35fa7_row0_col4, #T_35fa7_row1_col1, #T_35fa7_row1_col2, #T_35fa7_row1_col4 {
#   color: #307fc1;
# }
# </style>
# <table id="T_35fa7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35fa7_level0_col0" class="col_heading level0 col0" >column</th>
#       <th id="T_35fa7_level0_col1" class="col_heading level0 col1" >is_key</th>
#       <th id="T_35fa7_level0_col2" class="col_heading level0 col2" >index</th>
#       <th id="T_35fa7_level0_col3" class="col_heading level0 col3" >type</th>
#       <th id="T_35fa7_level0_col4" class="col_heading level0 col4" >has_default</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35fa7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35fa7_row0_col0" class="data row0 col0" >c1</td>
#       <td id="T_35fa7_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_35fa7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_35fa7_row0_col3" class="data row0 col3" >Any?</td>
#       <td id="T_35fa7_row0_col4" class="data row0 col4" >False</td>
#     </tr>
#     <tr>
#       <th id="T_35fa7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35fa7_row1_col0" class="data row1 col0" >c2</td>
#       <td id="T_35fa7_row1_col1" class="data row1 col1" >True</td>
#       <td id="T_35fa7_row1_col2" class="data row1 col2" >1</td>
#       <td id="T_35fa7_row1_col3" class="data row1 col3" >Any?</td>
#       <td id="T_35fa7_row1_col4" class="data row1 col4" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Stored relations can be accessed by using an asterisk `*` before the name:

# %%
?[a, b] := *stored[a, b]
# Out:
# <style type="text/css">
# </style>
# <table id="T_81a65">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81a65_level0_col0" class="col_heading level0 col0" >a</th>
#       <th id="T_81a65_level0_col1" class="col_heading level0 col1" >b</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# Unlike relations defined inline, the columns of stored relations have fixed names.
# You can take advantage of this by selectively referring to columns by name,
# especially if you have a lot of columns:

# %%
?[a, b] := *stored{l2: b, l1: a}
# Out:
# eval::named_field_not_found
#
#   × stored relation 'stored' does not have field 'l1'
#    ╭─[1:1]
#  1 │ ?[a, b] := *stored{l2: b, l1: a}
#    ·            ─────────────────────
#  2 │
#    ╰────

# %% [markdown]
# If the binding is the same as the column name, you can omit the binding:

# %%
?[l2] := *stored{l2}
# Out:
# eval::named_field_not_found
#
#   × stored relation 'stored' does not have field 'l2'
#    ╭─[1:1]
#  1 │ ?[l2] := *stored{l2}
#    ·          ───────────
#  2 │
#    ╰────

# %% [markdown]
# Use `:rm` to remove data:

# %%
?[l1, l2] <- [['e', 'E']]
    
:rm stored {l1, l2}
# Out:
# eval::required_col_not_found
#
#   × required column l1 not found

# %%
?[l1, l2] := *stored[l1, l2]
# Out:
# <style type="text/css">
# </style>
# <table id="T_9b548">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b548_level0_col0" class="col_heading level0 col0" >l1</th>
#       <th id="T_9b548_level0_col1" class="col_heading level0 col1" >l2</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# Use `::remove` (double colon!) to get rid of a stored relation:

# %%
::remove stored
# Out:
# <style type="text/css">
# #T_97668_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_97668">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97668_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97668_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97668_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %%
::relations
# Out:
# <style type="text/css">
# #T_04643_row0_col0, #T_04643_row0_col2, #T_04643_row0_col8, #T_04643_row1_col0, #T_04643_row1_col2, #T_04643_row1_col8 {
#   color: black;
# }
# #T_04643_row0_col1, #T_04643_row0_col3, #T_04643_row0_col4, #T_04643_row0_col5, #T_04643_row0_col6, #T_04643_row0_col7, #T_04643_row1_col1, #T_04643_row1_col3, #T_04643_row1_col4, #T_04643_row1_col5, #T_04643_row1_col6, #T_04643_row1_col7 {
#   color: #307fc1;
# }
# </style>
# <table id="T_04643">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04643_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_04643_level0_col1" class="col_heading level0 col1" >arity</th>
#       <th id="T_04643_level0_col2" class="col_heading level0 col2" >access_level</th>
#       <th id="T_04643_level0_col3" class="col_heading level0 col3" >n_keys</th>
#       <th id="T_04643_level0_col4" class="col_heading level0 col4" >n_non_keys</th>
#       <th id="T_04643_level0_col5" class="col_heading level0 col5" >n_put_triggers</th>
#       <th id="T_04643_level0_col6" class="col_heading level0 col6" >n_rm_triggers</th>
#       <th id="T_04643_level0_col7" class="col_heading level0 col7" >n_replace_triggers</th>
#       <th id="T_04643_level0_col8" class="col_heading level0 col8" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04643_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04643_row0_col0" class="data row0 col0" >dept_info</td>
#       <td id="T_04643_row0_col1" class="data row0 col1" >4</td>
#       <td id="T_04643_row0_col2" class="data row0 col2" >normal</td>
#       <td id="T_04643_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_04643_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_04643_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_04643_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_04643_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_04643_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_04643_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04643_row1_col0" class="data row1 col0" >fd</td>
#       <td id="T_04643_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_04643_row1_col2" class="data row1 col2" >normal</td>
#       <td id="T_04643_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_04643_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_04643_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_04643_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_04643_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_04643_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We've now seen a variety of Cozo queries. They all have one or more rules, one of which will have the name ? which determines which variables are the _result_ of the query.
#
# A query can also have one or more operations such as :put, which are executed after the query and can use its results. These operations might also change the query in some way, by limiting the number of results, sorting, paginating and so on.

# %% [markdown]
# Stored relations can have triggers. These are discussed in detail [here](stored.rst).
#
# Before continuing, let's remove the stored relation we introduced:

# %%
::remove fd
# Out:
# <style type="text/css">
# #T_12bfb_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_12bfb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12bfb_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12bfb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_12bfb_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Command blocks
#
# Cozo executes the entire script you send to it in a single transaction. You can do multiple query-command blocks by wrapping each block in curly braces. The blocks are executed in sequence and either all of them succeed or none of them do and the state rolls back. The result returned to a client is whatever is in the last block. Like this:

# %%
{?[a] <- [[1], [2], [3]]; :replace test {a}}
{?[a] <- []; :replace test2 {a}}
# %swap test test2
# %return test
# Out:
# <style type="text/css">
# </style>
# <table id="T_e6a40">
#   <thead>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# ## Graphs
#
# Now let's consider a graph stored as a relation:

# %%
?[loving, loved] <- [['alice', 'eve'],
                     ['bob', 'alice'],
                     ['eve', 'alice'],
                     ['eve', 'bob'],
                     ['eve', 'charlie'],
                     ['charlie', 'eve'],
                     ['david', 'george'],
                     ['george', 'george']]

:replace love {loving, loved}
# Out:
# <style type="text/css">
# #T_cecd1_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_cecd1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cecd1_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cecd1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cecd1_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The graph we have created reads like "Alice loves Eve, Bob loves Alice", "nobody loves David, David loves George, but George only loves himself", and so on.
# Here we used `:replace` instead of `:create`. The difference is that if `love` already exists, it will be wiped and replaced with the new data given.
#
# We can investigate competing interests:

# %%
?[loved_by_b_e] := *love['eve', loved_by_b_e], 
                   *love['bob', loved_by_b_e]
# Out:
# <style type="text/css">
# #T_419e4_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_419e4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_419e4_level0_col0" class="col_heading level0 col0" >loved_by_b_e</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_419e4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_419e4_row0_col0" class="data row0 col0" >alice</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It fells natural here to use the `or` keyword:

# %%
?[loved_by_b_e] := *love['eve', loved_by_b_e] or *love['bob', loved_by_b_e], 
                   loved_by_b_e != 'bob', 
                   loved_by_b_e != 'eve'
# Out:
# <style type="text/css">
# #T_fb8ca_row0_col0, #T_fb8ca_row1_col0 {
#   color: black;
# }
# </style>
# <table id="T_fb8ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb8ca_level0_col0" class="col_heading level0 col0" >loved_by_b_e</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb8ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb8ca_row0_col0" class="data row0 col0" >alice</td>
#     </tr>
#     <tr>
#       <th id="T_fb8ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb8ca_row1_col0" class="data row1 col0" >charlie</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Compare this with multiple rule definitions under the same name:

# %%
?[loved_by_b_e] := *love['eve', loved_by_b_e], 
                   loved_by_b_e != 'bob', 
                   loved_by_b_e != 'eve'
?[loved_by_b_e] := *love['bob', loved_by_b_e], 
                   loved_by_b_e != 'bob', 
                   loved_by_b_e != 'eve'
# Out:
# <style type="text/css">
# #T_b8e71_row0_col0, #T_b8e71_row1_col0 {
#   color: black;
# }
# </style>
# <table id="T_b8e71">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8e71_level0_col0" class="col_heading level0 col0" >loved_by_b_e</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8e71_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b8e71_row0_col0" class="data row0 col0" >alice</td>
#     </tr>
#     <tr>
#       <th id="T_b8e71_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b8e71_row1_col0" class="data row1 col0" >charlie</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# When you have multiple definitions of the same inline rule, the rule heads must be compatible. Only inline rules can have multiple definitions.
#
# ### Negation
#
# Negation of _expressions_ should be familiar:

# %%
?[loved] := *love[person, loved], !ends_with(person, 'e')
# Out:
# <style type="text/css">
# #T_4e2ca_row0_col0, #T_4e2ca_row1_col0 {
#   color: black;
# }
# </style>
# <table id="T_4e2ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4e2ca_level0_col0" class="col_heading level0 col0" >loved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4e2ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4e2ca_row0_col0" class="data row0 col0" >alice</td>
#     </tr>
#     <tr>
#       <th id="T_4e2ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4e2ca_row1_col0" class="data row1 col0" >george</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Rule applications can also be negated, not with the `!` operator, but with the `not` keyword:

# %%
?[loved_by_e_not_b] := *love['eve', loved_by_e_not_b], 
                       not *love['bob', loved_by_e_not_b]
# Out:
# <style type="text/css">
# #T_4547a_row0_col0, #T_4547a_row1_col0 {
#   color: black;
# }
# </style>
# <table id="T_4547a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4547a_level0_col0" class="col_heading level0 col0" >loved_by_e_not_b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4547a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4547a_row0_col0" class="data row0 col0" >bob</td>
#     </tr>
#     <tr>
#       <th id="T_4547a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4547a_row1_col0" class="data row1 col0" >charlie</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There are two sets of logical operations in Cozo, one set that acts on the level of expressions, and another set that acts within the expression (we say they work on _atoms_):
#
# * For atoms: `,` or `and` (conjunction), `or` (disjunction), `not` (negation)
# * For expressions: `&&` (conjunction), `||` (disjunction), `!` (negation)
#
# The difference between `,` and `and` is operator precedence: `and` has higher precedence than `or`, whereas `,` has lower precedence than `or`.
#
# There is a _safety rule_ for negation:

# %%
?[not_loved_by_b] := not *love['bob', not_loved_by_b]
# Out:
# eval::unbound_symb_in_head
#
#   × Symbol 'not_loved_by_b' in rule head is unbound
#    ╭─[1:1]
#  1 │ ?[not_loved_by_b] := not *love['bob', not_loved_by_b]
#    ·   ──────────────
#  2 │
#    ╰────
#   help: Note that symbols occurring only in negated positions are not considered bound

# %% [markdown]
# This query is forbidden because the resulting relation is infinite.
# For example, 'gold' should be in the result, since _according to the facts stored in the database_,
# Bob has no interest in 'gold'.
#
# To make our query finite, we have to explicitly give our query a _closed world_:

# %%
the_population[p] := *love[p, _a]
the_population[p] := *love[_a, p]

?[not_loved_by_b] := the_population[not_loved_by_b], 
                     not *love['bob', not_loved_by_b]
# Out:
# <style type="text/css">
# #T_aae97_row0_col0, #T_aae97_row1_col0, #T_aae97_row2_col0, #T_aae97_row3_col0, #T_aae97_row4_col0 {
#   color: black;
# }
# </style>
# <table id="T_aae97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aae97_level0_col0" class="col_heading level0 col0" >not_loved_by_b</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aae97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aae97_row0_col0" class="data row0 col0" >bob</td>
#     </tr>
#     <tr>
#       <th id="T_aae97_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_aae97_row1_col0" class="data row1 col0" >charlie</td>
#     </tr>
#     <tr>
#       <th id="T_aae97_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_aae97_row2_col0" class="data row2 col0" >david</td>
#     </tr>
#     <tr>
#       <th id="T_aae97_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_aae97_row3_col0" class="data row3 col0" >eve</td>
#     </tr>
#     <tr>
#       <th id="T_aae97_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_aae97_row4_col0" class="data row4 col0" >george</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Recursion
#
# The single greatest advantage of Datalog over SQL is that recursive/graph queries area much simpler.
#
# Inline rules can apply other rules, and can have multiple definitions. If you combine these two, you get recursions:

# %%
alice_love_chain[person] := *love['alice', person]
alice_love_chain[person] := alice_love_chain[in_person], 
                            *love[in_person, person]

?[chained] := alice_love_chain[chained]
# Out:
# <style type="text/css">
# #T_1b900_row0_col0, #T_1b900_row1_col0, #T_1b900_row2_col0, #T_1b900_row3_col0 {
#   color: black;
# }
# </style>
# <table id="T_1b900">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b900_level0_col0" class="col_heading level0 col0" >chained</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b900_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b900_row0_col0" class="data row0 col0" >alice</td>
#     </tr>
#     <tr>
#       <th id="T_1b900_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b900_row1_col0" class="data row1 col0" >bob</td>
#     </tr>
#     <tr>
#       <th id="T_1b900_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b900_row2_col0" class="data row2 col0" >charlie</td>
#     </tr>
#     <tr>
#       <th id="T_1b900_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b900_row3_col0" class="data row3 col0" >eve</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You may object that you only need to be able to apply other rules to have recursion,
# without multiple definitions.
# Technically correct, but the resulting queries are not useful::

# %%
alice_love_chain[person] := alice_love_chain[in_person], 
                            *love[in_person, person]

?[chained] := alice_love_chain[chained]
# Out:
# <style type="text/css">
# </style>
# <table id="T_c5dab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c5dab_level0_col0" class="col_heading level0 col0" >chained</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# Similar to the negation case, if there is no way to _deduce_ a fact from the given facts,
# then the fact itself is considered false.
# You need multiple definitions to "bootstrap" the query.
#
# ### Aggregation
#
# _Aggregations_ are usually used to compute statistics. In Cozo, aggregations are applied in the head of inline rules:

# %%
?[person, count(loved_by)] := *love[loved_by, person]
# Out:
# <style type="text/css">
# #T_e8d67_row0_col0, #T_e8d67_row1_col0, #T_e8d67_row2_col0, #T_e8d67_row3_col0, #T_e8d67_row4_col0 {
#   color: black;
# }
# #T_e8d67_row0_col1, #T_e8d67_row1_col1, #T_e8d67_row2_col1, #T_e8d67_row3_col1, #T_e8d67_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_e8d67">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e8d67_level0_col0" class="col_heading level0 col0" >person</th>
#       <th id="T_e8d67_level0_col1" class="col_heading level0 col1" >count(loved_by)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e8d67_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e8d67_row0_col0" class="data row0 col0" >alice</td>
#       <td id="T_e8d67_row0_col1" class="data row0 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e8d67_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e8d67_row1_col0" class="data row1 col0" >bob</td>
#       <td id="T_e8d67_row1_col1" class="data row1 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8d67_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e8d67_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_e8d67_row2_col1" class="data row2 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e8d67_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e8d67_row3_col0" class="data row3 col0" >eve</td>
#       <td id="T_e8d67_row3_col1" class="data row3 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_e8d67_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e8d67_row4_col0" class="data row4 col0" >george</td>
#       <td id="T_e8d67_row4_col1" class="data row4 col1" >2</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The usual `sum`, `mean`, etc. are all available.
#
# Here is the [full list](aggregations.rst) of aggregations for you to play with.
#
# ### Query options
#
# We have seen query options like `:create`, `:put`, `:rm` for manipulating stored relations.
# There are also query options for controlling what is returned:

# %%
?[loving, loved] := *love{ loving, loved }

:limit 1
# Out:
# <style type="text/css">
# #T_01dfd_row0_col0, #T_01dfd_row0_col1 {
#   color: black;
# }
# </style>
# <table id="T_01dfd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_01dfd_level0_col0" class="col_heading level0 col0" >loving</th>
#       <th id="T_01dfd_level0_col1" class="col_heading level0 col1" >loved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_01dfd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_01dfd_row0_col0" class="data row0 col0" >alice</td>
#       <td id="T_01dfd_row0_col1" class="data row0 col1" >eve</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Next we want the result to be sorted by `loved` in descending order, then `loving` in ascending order, and skip the first row:

# %%
?[loving, loved] := *love{ loving, loved }

:order -loved, loving
:offset 1
# Out:
# <style type="text/css">
# #T_35ce0_row0_col0, #T_35ce0_row0_col1, #T_35ce0_row1_col0, #T_35ce0_row1_col1, #T_35ce0_row2_col0, #T_35ce0_row2_col1, #T_35ce0_row3_col0, #T_35ce0_row3_col1, #T_35ce0_row4_col0, #T_35ce0_row4_col1, #T_35ce0_row5_col0, #T_35ce0_row5_col1, #T_35ce0_row6_col0, #T_35ce0_row6_col1 {
#   color: black;
# }
# </style>
# <table id="T_35ce0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35ce0_level0_col0" class="col_heading level0 col0" >loving</th>
#       <th id="T_35ce0_level0_col1" class="col_heading level0 col1" >loved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35ce0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35ce0_row0_col0" class="data row0 col0" >george</td>
#       <td id="T_35ce0_row0_col1" class="data row0 col1" >george</td>
#     </tr>
#     <tr>
#       <th id="T_35ce0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35ce0_row1_col0" class="data row1 col0" >alice</td>
#       <td id="T_35ce0_row1_col1" class="data row1 col1" >eve</td>
#     </tr>
#     <tr>
#       <th id="T_35ce0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35ce0_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_35ce0_row2_col1" class="data row2 col1" >eve</td>
#     </tr>
#     <tr>
#       <th id="T_35ce0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35ce0_row3_col0" class="data row3 col0" >eve</td>
#       <td id="T_35ce0_row3_col1" class="data row3 col1" >charlie</td>
#     </tr>
#     <tr>
#       <th id="T_35ce0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35ce0_row4_col0" class="data row4 col0" >eve</td>
#       <td id="T_35ce0_row4_col1" class="data row4 col1" >bob</td>
#     </tr>
#     <tr>
#       <th id="T_35ce0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35ce0_row5_col0" class="data row5 col0" >bob</td>
#       <td id="T_35ce0_row5_col1" class="data row5 col1" >alice</td>
#     </tr>
#     <tr>
#       <th id="T_35ce0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_35ce0_row6_col0" class="data row6 col0" >eve</td>
#       <td id="T_35ce0_row6_col1" class="data row6 col1" >alice</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Putting `-` in front of variables in `:order` clause denotes reverse order. Nothing or `+` denotes the ascending order.
#
# The full list of query options are explained in [this chapter](queries.rst).
#
# ### Fixed rules
#
# We've seen how the `<-` syntax for constant rules is syntax sugar. The full syntax is:

# %%
?[] <~ Constant(data: [['hello', 'world', 'Cozo!']])
# Out:
# <style type="text/css">
# #T_0ed37_row0_col0, #T_0ed37_row0_col1, #T_0ed37_row0_col2 {
#   color: black;
# }
# </style>
# <table id="T_0ed37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ed37_level0_col0" class="col_heading level0 col0" >_0</th>
#       <th id="T_0ed37_level0_col1" class="col_heading level0 col1" >_1</th>
#       <th id="T_0ed37_level0_col2" class="col_heading level0 col2" >_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ed37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0ed37_row0_col0" class="data row0 col0" >hello</td>
#       <td id="T_0ed37_row0_col1" class="data row0 col1" >world</td>
#       <td id="T_0ed37_row0_col2" class="data row0 col2" >Cozo!</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here we are using the _fixed rule_ `Constant`, which takes one _option_ named `data`. The curly tail `<~` denotes a fixed rule.
#
# Fixed rules take input relations as arguments, apply custom logic to them and produce its output relation. They're functions that return relations, defined outside the Cozo engine itself (either built-in or loaded from a library or defined by the host language).
#
# The `Constant` fixed rule take zero input relations.
#
# If you are using Cozo in browser, `Constant` is the only fixed rule you can use. In all other cases your Cozo would have the graph algorithms module enabled, and all graph algorithms are implemented as fixed rules. As an example, let's find out who is most popular in the `love` graph by using the [PageRank](https://en.wikipedia.org/wiki/PageRank) algorithm:

# %%
?[person, page_rank] <~ PageRank(*love[])

:order -page_rank
# Out:
# <style type="text/css">
# #T_13878_row0_col0, #T_13878_row1_col0, #T_13878_row2_col0, #T_13878_row3_col0, #T_13878_row4_col0, #T_13878_row5_col0 {
#   color: black;
# }
# #T_13878_row0_col1, #T_13878_row1_col1, #T_13878_row2_col1, #T_13878_row3_col1, #T_13878_row4_col1, #T_13878_row5_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_13878">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13878_level0_col0" class="col_heading level0 col0" >person</th>
#       <th id="T_13878_level0_col1" class="col_heading level0 col1" >page_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13878_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13878_row0_col0" class="data row0 col0" >george</td>
#       <td id="T_13878_row0_col1" class="data row0 col1" >0.280443</td>
#     </tr>
#     <tr>
#       <th id="T_13878_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13878_row1_col0" class="data row1 col0" >eve</td>
#       <td id="T_13878_row1_col1" class="data row1 col1" >0.275376</td>
#     </tr>
#     <tr>
#       <th id="T_13878_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13878_row2_col0" class="data row2 col0" >alice</td>
#       <td id="T_13878_row2_col1" class="data row2 col1" >0.191205</td>
#     </tr>
#     <tr>
#       <th id="T_13878_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13878_row3_col0" class="data row3 col0" >bob</td>
#       <td id="T_13878_row3_col1" class="data row3 col1" >0.103023</td>
#     </tr>
#     <tr>
#       <th id="T_13878_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13878_row4_col0" class="data row4 col0" >charlie</td>
#       <td id="T_13878_row4_col1" class="data row4 col1" >0.103023</td>
#     </tr>
#     <tr>
#       <th id="T_13878_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13878_row5_col0" class="data row5 col0" >david</td>
#       <td id="T_13878_row5_col1" class="data row5 col1" >0.025000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Here the input relation is the stored relation `*love` (as noted above, you will receive an error if you run this in the WASM implementation).
#
# Each fixed rule is different: [here](algorithms.rst) is the full list.

# %%
::remove love
# Out:
# <style type="text/css">
# #T_54a20_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_54a20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_54a20_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_54a20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_54a20_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Time travel
#
# A very useful capability of Cozo is the ability to time travel in a stored relation.
# Usually when you `:put` into a relation, the old value is overwritten; and when you `:rm`, the row is
# completely gone. But the old values can be of great value — we have a [short story](releases/v0.4.md) about it.
#
# In this case, _time travel_ is the solution: instead of storing _current_ facts, the stored relation stores the complete history of facts, at least all the available history as history itself unfolds.
#
# If you believe that you don't want this functionality at all, you can skip to the next section.
# At Cozo we adopt the "zero-cost, zero-mental-overhead abstraction" philosophy:
# if you don't use a functionality, you don't pay the performance or cognitive overhead.
#
# Let's have a simple example: storing the head of state of countries.
# First we have to create a new stored relation:

# %%
:create hos {state: String, year: Validity => hos: String}
# Out:
# <style type="text/css">
# #T_d4f1c_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_d4f1c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d4f1c_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d4f1c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d4f1c_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `hos` is shorthand for "head of state". The only thing different about this relation is that we are giving `year` the type `Validity`.
# You can think of validity as a list of two elements, the first element being an integer and the second element being a boolean.
# The integer indicates the "time" of the fact recorded by the row, the boolean, if _true_, indicates that the new version of the row holds starting from the indicated time; if the boolean is _false_, the row is deleted at this time.
#
# Note that the integer only identifies a temporal sequence to Cozo. What sequence you use is up to you. UNIX _Epoch_ is the default, as we will see.
#
# Now let's insert some data:

# %%
?[state, year, hos] <- [['US', [2001, true], 'Bush'],
                        ['US', [2005, true], 'Bush'],
                        ['US', [2009, true], 'Obama'],
                        ['US', [2013, true], 'Obama'],
                        ['US', [2017, true], 'Trump'],
                        ['US', [2021, true], 'Biden']]

:put hos {state, year => hos}
# Out:
# <style type="text/css">
# #T_f84f9_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_f84f9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f84f9_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f84f9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f84f9_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It is OK to assert a still valid fact again, as we have done above. You can use this relation like a normal relation:

# %%
?[state, year, hos] := *hos{state, year, hos}
# Out:
# <style type="text/css">
# #T_29230_row0_col0, #T_29230_row0_col2, #T_29230_row1_col0, #T_29230_row1_col2, #T_29230_row2_col0, #T_29230_row2_col2, #T_29230_row3_col0, #T_29230_row3_col2, #T_29230_row4_col0, #T_29230_row4_col2, #T_29230_row5_col0, #T_29230_row5_col2 {
#   color: black;
# }
# #T_29230_row0_col1, #T_29230_row1_col1, #T_29230_row2_col1, #T_29230_row3_col1, #T_29230_row4_col1, #T_29230_row5_col1 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_29230">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_29230_level0_col0" class="col_heading level0 col0" >state</th>
#       <th id="T_29230_level0_col1" class="col_heading level0 col1" >year</th>
#       <th id="T_29230_level0_col2" class="col_heading level0 col2" >hos</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_29230_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_29230_row0_col0" class="data row0 col0" >US</td>
#       <td id="T_29230_row0_col1" class="data row0 col1" >[2021, True]</td>
#       <td id="T_29230_row0_col2" class="data row0 col2" >Biden</td>
#     </tr>
#     <tr>
#       <th id="T_29230_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_29230_row1_col0" class="data row1 col0" >US</td>
#       <td id="T_29230_row1_col1" class="data row1 col1" >[2017, True]</td>
#       <td id="T_29230_row1_col2" class="data row1 col2" >Trump</td>
#     </tr>
#     <tr>
#       <th id="T_29230_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_29230_row2_col0" class="data row2 col0" >US</td>
#       <td id="T_29230_row2_col1" class="data row2 col1" >[2013, True]</td>
#       <td id="T_29230_row2_col2" class="data row2 col2" >Obama</td>
#     </tr>
#     <tr>
#       <th id="T_29230_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_29230_row3_col0" class="data row3 col0" >US</td>
#       <td id="T_29230_row3_col1" class="data row3 col1" >[2009, True]</td>
#       <td id="T_29230_row3_col2" class="data row3 col2" >Obama</td>
#     </tr>
#     <tr>
#       <th id="T_29230_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_29230_row4_col0" class="data row4 col0" >US</td>
#       <td id="T_29230_row4_col1" class="data row4 col1" >[2005, True]</td>
#       <td id="T_29230_row4_col2" class="data row4 col2" >Bush</td>
#     </tr>
#     <tr>
#       <th id="T_29230_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_29230_row5_col0" class="data row5 col0" >US</td>
#       <td id="T_29230_row5_col1" class="data row5 col1" >[2001, True]</td>
#       <td id="T_29230_row5_col2" class="data row5 col2" >Bush</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The curious thing is that it is sorted _descendingly_ by year. Validity sorts descendingly.
#
# For any stored relation that has type `Validity` at the _last_ slot of the key, the time-travel capability is enabled.
# Say you have forgotten who the president of the US was in 2019. Easy:

# %%
?[hos, year] := *hos{state: 'US', year, hos @ 2019}
# Out:
# <style type="text/css">
# #T_cdfa6_row0_col0 {
#   color: black;
# }
# #T_cdfa6_row0_col1 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_cdfa6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cdfa6_level0_col0" class="col_heading level0 col0" >hos</th>
#       <th id="T_cdfa6_level0_col1" class="col_heading level0 col1" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cdfa6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cdfa6_row0_col0" class="data row0 col0" >Trump</td>
#       <td id="T_cdfa6_row0_col1" class="data row0 col1" >[2017, True]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In your answer you also got the year that this fact was last known to be true.
#
# You also don't know about the year 2099:

# %%
?[hos, year] := *hos{state: 'US', year, hos @ 2099}
# Out:
# <style type="text/css">
# #T_97340_row0_col0 {
#   color: black;
# }
# #T_97340_row0_col1 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_97340">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_97340_level0_col0" class="col_heading level0 col0" >hos</th>
#       <th id="T_97340_level0_col1" class="col_heading level0 col1" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_97340_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_97340_row0_col0" class="data row0 col0" >Biden</td>
#       <td id="T_97340_row0_col1" class="data row0 col1" >[2021, True]</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That certainly doesn't look right. Let's fix it by _retracting_ facts on or after 2025, and only inserting them back when we have the sure facts:

# %%
?[state, year, hos] <- [['US', [2025, false], '']]

:put hos {state, year => hos}
# Out:
# <style type="text/css">
# #T_6bf48_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_6bf48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6bf48_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6bf48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6bf48_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As we have hinted, you retract facts by _putting_ a retraction. Now let's run the query again:

# %%
?[hos, year] := *hos{state: 'US', year, hos @ 2099}
# Out:
# <style type="text/css">
# </style>
# <table id="T_5524e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5524e_level0_col0" class="col_heading level0 col0" >hos</th>
#       <th id="T_5524e_level0_col1" class="col_heading level0 col1" >year</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table>

# %% [markdown]
# Since the database does not contain facts on or after 2025, your query returns empty.
#
# This functionality is flexible: you can mix different periods in the same query:

# %%
?[hos2018, hos2010] := *hos{state: 'US', hos: hos2018 @ 2018}, 
                       *hos{state: 'US', hos: hos2010 @ 2010}
# Out:
# <style type="text/css">
# #T_7d72e_row0_col0, #T_7d72e_row0_col1 {
#   color: black;
# }
# </style>
# <table id="T_7d72e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d72e_level0_col0" class="col_heading level0 col0" >hos2018</th>
#       <th id="T_7d72e_level0_col1" class="col_heading level0 col1" >hos2010</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d72e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d72e_row0_col0" class="data row0 col0" >Trump</td>
#       <td id="T_7d72e_row0_col1" class="data row0 col1" >Obama</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As the relation `hos` is just a normal relation, you can still `rm` facts from it, in which case the facts are irretrievably gone. Whether that's desirable is up to you: the database gives you the choice of how you want to use it, and trusts that you know how to use it correctly for your use case.
#
# First let's create a new stored relation to store people's moods:

# %%
:create mood {name: String, at: Validity => mood: String}
# Out:
# <style type="text/css">
# #T_7d45d_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_7d45d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d45d_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d45d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7d45d_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# I want to record my mood now:

# %%
?[name, at, mood] <- [['me', 'ASSERT', 'curious']]
:put mood {name, at => mood}
# Out:
# <style type="text/css">
# #T_21077_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_21077">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_21077_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_21077_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_21077_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Instead of giving a list of two elements as we have done above, we have simply used the string `ASSERT`, and the system will know that we mean an assertion of a _current_ fact, and you guessed it, the value used is the current UNIX Epoch.

# %%
?[name, at, mood] := *mood{name, at, mood}
# Out:
# <style type="text/css">
# #T_1c5c8_row0_col0, #T_1c5c8_row0_col2 {
#   color: black;
# }
# #T_1c5c8_row0_col1 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_1c5c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1c5c8_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1c5c8_level0_col1" class="col_heading level0 col1" >at</th>
#       <th id="T_1c5c8_level0_col2" class="col_heading level0 col2" >mood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1c5c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1c5c8_row0_col0" class="data row0 col0" >me</td>
#       <td id="T_1c5c8_row0_col1" class="data row0 col1" >[1700569902203327, True]</td>
#       <td id="T_1c5c8_row0_col2" class="data row0 col2" >curious</td>
#     </tr>
#   </tbody>
# </table>

# %%
?[name, time, mood] := *mood{name, at, mood}, 
                       time = format_timestamp(at)
# Out:
# <style type="text/css">
# #T_3e085_row0_col0, #T_3e085_row0_col1, #T_3e085_row0_col2 {
#   color: black;
# }
# </style>
# <table id="T_3e085">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e085_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_3e085_level0_col1" class="col_heading level0 col1" >time</th>
#       <th id="T_3e085_level0_col2" class="col_heading level0 col2" >mood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e085_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e085_row0_col0" class="data row0 col0" >me</td>
#       <td id="T_3e085_row0_col1" class="data row0 col1" >2023-11-21T12:31:42.203+00:00</td>
#       <td id="T_3e085_row0_col2" class="data row0 col2" >curious</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# To query for current facts, use the string `NOW` in the validity specification:

# %%
?[name, time, mood] := *mood{name, at, mood @ 'NOW'}, 
                       time = format_timestamp(at)
# Out:
# <style type="text/css">
# #T_91977_row0_col0, #T_91977_row0_col1, #T_91977_row0_col2 {
#   color: black;
# }
# </style>
# <table id="T_91977">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91977_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_91977_level0_col1" class="col_heading level0 col1" >time</th>
#       <th id="T_91977_level0_col2" class="col_heading level0 col2" >mood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91977_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_91977_row0_col0" class="data row0 col0" >me</td>
#       <td id="T_91977_row0_col1" class="data row0 col1" >2023-11-21T12:31:42.203+00:00</td>
#       <td id="T_91977_row0_col2" class="data row0 col2" >curious</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can put in facts with manual timestamps as before, so it is possible that your database contains facts about the future.
# Let's do just that. Instead of giving a mysterious string of numerals, you can use a string for the timestamp:

# %%
?[name, at, mood] <- [['me', '2030-01-01T00:00:00.000+00:00', 'hopeful']]
:put mood {name, at => mood}
# Out:
# <style type="text/css">
# #T_a2874_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_a2874">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2874_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2874_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a2874_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Since this is in the future, it shouldn't affect `NOW`:

# %%
?[name, time, mood] := *mood{name, at, mood @ 'NOW'}, 
                       time = format_timestamp(at)
# Out:
# <style type="text/css">
# #T_7c9b5_row0_col0, #T_7c9b5_row0_col1, #T_7c9b5_row0_col2 {
#   color: black;
# }
# </style>
# <table id="T_7c9b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c9b5_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_7c9b5_level0_col1" class="col_heading level0 col1" >time</th>
#       <th id="T_7c9b5_level0_col2" class="col_heading level0 col2" >mood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c9b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c9b5_row0_col0" class="data row0 col0" >me</td>
#       <td id="T_7c9b5_row0_col1" class="data row0 col1" >2023-11-21T12:31:42.203+00:00</td>
#       <td id="T_7c9b5_row0_col2" class="data row0 col2" >curious</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# In this case, there is also `END` for the validity specification, meaning to extract facts at the end of time:

# %%
?[name, time, mood] := *mood{name, at, mood @ 'END'}, 
                       time = format_timestamp(at)
# Out:
# <style type="text/css">
# #T_1452b_row0_col0, #T_1452b_row0_col1, #T_1452b_row0_col2 {
#   color: black;
# }
# </style>
# <table id="T_1452b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1452b_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_1452b_level0_col1" class="col_heading level0 col1" >time</th>
#       <th id="T_1452b_level0_col2" class="col_heading level0 col2" >mood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1452b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1452b_row0_col0" class="data row0 col0" >me</td>
#       <td id="T_1452b_row0_col1" class="data row0 col1" >2030-01-01T00:00:00+00:00</td>
#       <td id="T_1452b_row0_col2" class="data row0 col2" >hopeful</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Retraction at the current timestamp can be done with the string `RETRACT`:

# %%
?[name, at, mood] <- [['me', 'RETRACT', '']]
:put mood {name, at => mood}
# Out:
# <style type="text/css">
# #T_0b581_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_0b581">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0b581_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0b581_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0b581_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Retraction placed in the future can also be done with stringy timestamps by prefixing with `~`:

# %%
?[name, at, mood] <- [['me', '~9999-01-01T00:00:00.000+00:00', 'who cares']]
:put mood {name, at => mood}
# Out:
# <style type="text/css">
# #T_aae97_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_aae97">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_aae97_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aae97_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_aae97_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now let's look at the complete history:

# %%
?[name, time, is_assert, mood] := *mood{name, at, mood}, 
                                  time = format_timestamp(at), 
                                  is_assert = to_bool(at)
# Out:
# <style type="text/css">
# #T_882a3_row0_col0, #T_882a3_row0_col1, #T_882a3_row0_col3, #T_882a3_row1_col0, #T_882a3_row1_col1, #T_882a3_row1_col3, #T_882a3_row2_col0, #T_882a3_row2_col1, #T_882a3_row2_col3, #T_882a3_row3_col0, #T_882a3_row3_col1, #T_882a3_row3_col3 {
#   color: black;
# }
# #T_882a3_row0_col2, #T_882a3_row1_col2, #T_882a3_row2_col2, #T_882a3_row3_col2 {
#   color: #307fc1;
# }
# </style>
# <table id="T_882a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_882a3_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_882a3_level0_col1" class="col_heading level0 col1" >time</th>
#       <th id="T_882a3_level0_col2" class="col_heading level0 col2" >is_assert</th>
#       <th id="T_882a3_level0_col3" class="col_heading level0 col3" >mood</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_882a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_882a3_row0_col0" class="data row0 col0" >me</td>
#       <td id="T_882a3_row0_col1" class="data row0 col1" >2023-11-21T12:31:42.203+00:00</td>
#       <td id="T_882a3_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_882a3_row0_col3" class="data row0 col3" >curious</td>
#     </tr>
#     <tr>
#       <th id="T_882a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_882a3_row1_col0" class="data row1 col0" >me</td>
#       <td id="T_882a3_row1_col1" class="data row1 col1" >2023-11-21T12:31:46.232+00:00</td>
#       <td id="T_882a3_row1_col2" class="data row1 col2" >False</td>
#       <td id="T_882a3_row1_col3" class="data row1 col3" ></td>
#     </tr>
#     <tr>
#       <th id="T_882a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_882a3_row2_col0" class="data row2 col0" >me</td>
#       <td id="T_882a3_row2_col1" class="data row2 col1" >2030-01-01T00:00:00+00:00</td>
#       <td id="T_882a3_row2_col2" class="data row2 col2" >True</td>
#       <td id="T_882a3_row2_col3" class="data row2 col3" >hopeful</td>
#     </tr>
#     <tr>
#       <th id="T_882a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_882a3_row3_col0" class="data row3 col0" >me</td>
#       <td id="T_882a3_row3_col1" class="data row3 col1" >9999-01-01T00:00:00+00:00</td>
#       <td id="T_882a3_row3_col2" class="data row3 col2" >False</td>
#       <td id="T_882a3_row3_col3" class="data row3 col3" >who cares</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# This time-travel facility is much faster than what you get if you try to implement it directly with Datalog: see the [note](releases/v0.4.md) for more details. Some further technical details of time travel is discussed in its own [chapter](timetravel.rst).

# %%
::remove mood, hos
# Out:
# <style type="text/css">
# #T_00503_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_00503">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_00503_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_00503_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_00503_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Extended example: the air routes dataset
#
# Now you have a basic understanding of using the various constructs of Cozo, let's deal with a small real-world dataset, with about 3700 nodes and 57000 edges.
#
# The data we are going to use, and many examples that we will present, are adapted from the book [Practical Gremlin](https://kelvinlawrence.net/book/Gremlin-Graph-Guide.html). Gremlin is an imperative query language for graphs, a very different take compared to Datalog.
#
# First, let's create the stored relations we want (wrapping queries in braces allows you to execute several queries together atomically):

# %%
{:create airport {
    code: String 
    => 
    icao: String, 
    desc: String, 
    region: String, 
    runways: Int, 
    longest: Float, 
    elev: Float, 
    country: String, 
    city: String, 
    lat: Float, 
    lon: Float
}}
{:create country {
    code: String
    =>
    desc: String
}}
{:create continent {
    code: String
    =>
    desc: String
}}
{:create contain { entity: String, contained: String }}
{:create route { fr: String, to: String => dist: Float }}
# Out:
# <style type="text/css">
# #T_3c393_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_3c393">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c393_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c393_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c393_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The next command applies only if you are using Jupyter notebooks: it downloads a JSON file containing the data and imports it into the database.
# The commented out line shows how to do the same thing with a local file. If you are using the Cozo WASM interface, click the "Import from URL" or the "Import from File" icon,
# and paste in the address.

# %%
# %cozo_import_remote_file 'https://raw.githubusercontent.com/cozodb/cozo/dev/cozo-core/tests/air-routes.json'
# %cozo_import_local_file '../../cozo/cozo-core/tests/air-routes.json'

# %% [markdown]
# If you are using the `cozo repl` command line, the command to use instead is simply
#
# ```
# %import https://raw.githubusercontent.com/cozodb/cozo/dev/cozo-core/tests/air-routes.json
# ```
#
# You can replace the URL with the path to a local file as well. Other environments also have ways to do the same thing: refer to the respective documentations.
#
# If you feel that the above is too much magic, we will show you the "hard way" of importing the same data at the end of this tutorial. For now let's move on.
#
# Let's verify all the relations we want are there:

# %%
::relations
# Out:
# <style type="text/css">
# #T_73b1e_row0_col0, #T_73b1e_row0_col2, #T_73b1e_row0_col8, #T_73b1e_row1_col0, #T_73b1e_row1_col2, #T_73b1e_row1_col8, #T_73b1e_row2_col0, #T_73b1e_row2_col2, #T_73b1e_row2_col8, #T_73b1e_row3_col0, #T_73b1e_row3_col2, #T_73b1e_row3_col8, #T_73b1e_row4_col0, #T_73b1e_row4_col2, #T_73b1e_row4_col8, #T_73b1e_row5_col0, #T_73b1e_row5_col2, #T_73b1e_row5_col8, #T_73b1e_row6_col0, #T_73b1e_row6_col2, #T_73b1e_row6_col8, #T_73b1e_row7_col0, #T_73b1e_row7_col2, #T_73b1e_row7_col8 {
#   color: black;
# }
# #T_73b1e_row0_col1, #T_73b1e_row0_col3, #T_73b1e_row0_col4, #T_73b1e_row0_col5, #T_73b1e_row0_col6, #T_73b1e_row0_col7, #T_73b1e_row1_col1, #T_73b1e_row1_col3, #T_73b1e_row1_col4, #T_73b1e_row1_col5, #T_73b1e_row1_col6, #T_73b1e_row1_col7, #T_73b1e_row2_col1, #T_73b1e_row2_col3, #T_73b1e_row2_col4, #T_73b1e_row2_col5, #T_73b1e_row2_col6, #T_73b1e_row2_col7, #T_73b1e_row3_col1, #T_73b1e_row3_col3, #T_73b1e_row3_col4, #T_73b1e_row3_col5, #T_73b1e_row3_col6, #T_73b1e_row3_col7, #T_73b1e_row4_col1, #T_73b1e_row4_col3, #T_73b1e_row4_col4, #T_73b1e_row4_col5, #T_73b1e_row4_col6, #T_73b1e_row4_col7, #T_73b1e_row5_col1, #T_73b1e_row5_col3, #T_73b1e_row5_col4, #T_73b1e_row5_col5, #T_73b1e_row5_col6, #T_73b1e_row5_col7, #T_73b1e_row6_col1, #T_73b1e_row6_col3, #T_73b1e_row6_col4, #T_73b1e_row6_col5, #T_73b1e_row6_col6, #T_73b1e_row6_col7, #T_73b1e_row7_col1, #T_73b1e_row7_col3, #T_73b1e_row7_col4, #T_73b1e_row7_col5, #T_73b1e_row7_col6, #T_73b1e_row7_col7 {
#   color: #307fc1;
# }
# </style>
# <table id="T_73b1e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73b1e_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_73b1e_level0_col1" class="col_heading level0 col1" >arity</th>
#       <th id="T_73b1e_level0_col2" class="col_heading level0 col2" >access_level</th>
#       <th id="T_73b1e_level0_col3" class="col_heading level0 col3" >n_keys</th>
#       <th id="T_73b1e_level0_col4" class="col_heading level0 col4" >n_non_keys</th>
#       <th id="T_73b1e_level0_col5" class="col_heading level0 col5" >n_put_triggers</th>
#       <th id="T_73b1e_level0_col6" class="col_heading level0 col6" >n_rm_triggers</th>
#       <th id="T_73b1e_level0_col7" class="col_heading level0 col7" >n_replace_triggers</th>
#       <th id="T_73b1e_level0_col8" class="col_heading level0 col8" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73b1e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73b1e_row0_col0" class="data row0 col0" >airport</td>
#       <td id="T_73b1e_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_73b1e_row0_col2" class="data row0 col2" >normal</td>
#       <td id="T_73b1e_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_73b1e_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_73b1e_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_73b1e_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_73b1e_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_73b1e_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_73b1e_row1_col0" class="data row1 col0" >contain</td>
#       <td id="T_73b1e_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_73b1e_row1_col2" class="data row1 col2" >normal</td>
#       <td id="T_73b1e_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_73b1e_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_73b1e_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_73b1e_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_73b1e_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_73b1e_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_73b1e_row2_col0" class="data row2 col0" >continent</td>
#       <td id="T_73b1e_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_73b1e_row2_col2" class="data row2 col2" >normal</td>
#       <td id="T_73b1e_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_73b1e_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_73b1e_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_73b1e_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_73b1e_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_73b1e_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_73b1e_row3_col0" class="data row3 col0" >country</td>
#       <td id="T_73b1e_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_73b1e_row3_col2" class="data row3 col2" >normal</td>
#       <td id="T_73b1e_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_73b1e_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_73b1e_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_73b1e_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_73b1e_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_73b1e_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_73b1e_row4_col0" class="data row4 col0" >dept_info</td>
#       <td id="T_73b1e_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_73b1e_row4_col2" class="data row4 col2" >normal</td>
#       <td id="T_73b1e_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_73b1e_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_73b1e_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_73b1e_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_73b1e_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_73b1e_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_73b1e_row5_col0" class="data row5 col0" >route</td>
#       <td id="T_73b1e_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_73b1e_row5_col2" class="data row5 col2" >normal</td>
#       <td id="T_73b1e_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_73b1e_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_73b1e_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_73b1e_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_73b1e_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_73b1e_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_73b1e_row6_col0" class="data row6 col0" >test</td>
#       <td id="T_73b1e_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_73b1e_row6_col2" class="data row6 col2" >normal</td>
#       <td id="T_73b1e_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_73b1e_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_73b1e_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_73b1e_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_73b1e_row6_col7" class="data row6 col7" >0</td>
#       <td id="T_73b1e_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_73b1e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_73b1e_row7_col0" class="data row7 col0" >test2</td>
#       <td id="T_73b1e_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_73b1e_row7_col2" class="data row7 col2" >normal</td>
#       <td id="T_73b1e_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_73b1e_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_73b1e_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_73b1e_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_73b1e_row7_col7" class="data row7 col7" >0</td>
#       <td id="T_73b1e_row7_col8" class="data row7 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# While we are at it, let's lock all these tables to prevent accidentally changing their contents:

# %%
::access_level read_only airport, contain, continent, country, route
# Out:
# <style type="text/css">
# #T_752d2_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_752d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_752d2_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_752d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_752d2_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# More information about what this does is explained in [this chapter](sysops.rst).
#
# Let's just look at some data. Start with airports:

# %%
?[code, city, desc, region, runways, lat, lon] := *airport{code, city, desc, region, runways, lat, lon}
    
:limit 5
# Out:
# <style type="text/css">
# #T_d5461_row0_col0, #T_d5461_row0_col1, #T_d5461_row0_col2, #T_d5461_row0_col3, #T_d5461_row1_col0, #T_d5461_row1_col1, #T_d5461_row1_col2, #T_d5461_row1_col3, #T_d5461_row2_col0, #T_d5461_row2_col1, #T_d5461_row2_col2, #T_d5461_row2_col3, #T_d5461_row3_col0, #T_d5461_row3_col1, #T_d5461_row3_col2, #T_d5461_row3_col3, #T_d5461_row4_col0, #T_d5461_row4_col1, #T_d5461_row4_col2, #T_d5461_row4_col3 {
#   color: black;
# }
# #T_d5461_row0_col4, #T_d5461_row0_col5, #T_d5461_row0_col6, #T_d5461_row1_col4, #T_d5461_row1_col5, #T_d5461_row1_col6, #T_d5461_row2_col4, #T_d5461_row2_col5, #T_d5461_row2_col6, #T_d5461_row3_col4, #T_d5461_row3_col5, #T_d5461_row3_col6, #T_d5461_row4_col4, #T_d5461_row4_col5, #T_d5461_row4_col6 {
#   color: #307fc1;
# }
# </style>
# <table id="T_d5461">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5461_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_d5461_level0_col1" class="col_heading level0 col1" >city</th>
#       <th id="T_d5461_level0_col2" class="col_heading level0 col2" >desc</th>
#       <th id="T_d5461_level0_col3" class="col_heading level0 col3" >region</th>
#       <th id="T_d5461_level0_col4" class="col_heading level0 col4" >runways</th>
#       <th id="T_d5461_level0_col5" class="col_heading level0 col5" >lat</th>
#       <th id="T_d5461_level0_col6" class="col_heading level0 col6" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5461_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5461_row0_col0" class="data row0 col0" >AAA</td>
#       <td id="T_d5461_row0_col1" class="data row0 col1" >Anaa</td>
#       <td id="T_d5461_row0_col2" class="data row0 col2" >Anaa Airport</td>
#       <td id="T_d5461_row0_col3" class="data row0 col3" >PF-U-A</td>
#       <td id="T_d5461_row0_col4" class="data row0 col4" >1</td>
#       <td id="T_d5461_row0_col5" class="data row0 col5" >-17.352600</td>
#       <td id="T_d5461_row0_col6" class="data row0 col6" >-145.509995</td>
#     </tr>
#     <tr>
#       <th id="T_d5461_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5461_row1_col0" class="data row1 col0" >AAE</td>
#       <td id="T_d5461_row1_col1" class="data row1 col1" >Annabah</td>
#       <td id="T_d5461_row1_col2" class="data row1 col2" >Annaba Airport</td>
#       <td id="T_d5461_row1_col3" class="data row1 col3" >DZ-36</td>
#       <td id="T_d5461_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_d5461_row1_col5" class="data row1 col5" >36.822201</td>
#       <td id="T_d5461_row1_col6" class="data row1 col6" >7.809170</td>
#     </tr>
#     <tr>
#       <th id="T_d5461_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5461_row2_col0" class="data row2 col0" >AAL</td>
#       <td id="T_d5461_row2_col1" class="data row2 col1" >Aalborg</td>
#       <td id="T_d5461_row2_col2" class="data row2 col2" >Aalborg Airport</td>
#       <td id="T_d5461_row2_col3" class="data row2 col3" >DK-81</td>
#       <td id="T_d5461_row2_col4" class="data row2 col4" >2</td>
#       <td id="T_d5461_row2_col5" class="data row2 col5" >57.092759</td>
#       <td id="T_d5461_row2_col6" class="data row2 col6" >9.849243</td>
#     </tr>
#     <tr>
#       <th id="T_d5461_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5461_row3_col0" class="data row3 col0" >AAN</td>
#       <td id="T_d5461_row3_col1" class="data row3 col1" >Al Ain</td>
#       <td id="T_d5461_row3_col2" class="data row3 col2" >Al Ain International Airport</td>
#       <td id="T_d5461_row3_col3" class="data row3 col3" >AE-AZ</td>
#       <td id="T_d5461_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_d5461_row3_col5" class="data row3 col5" >24.261700</td>
#       <td id="T_d5461_row3_col6" class="data row3 col6" >55.609200</td>
#     </tr>
#     <tr>
#       <th id="T_d5461_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5461_row4_col0" class="data row4 col0" >AAQ</td>
#       <td id="T_d5461_row4_col1" class="data row4 col1" >Anapa</td>
#       <td id="T_d5461_row4_col2" class="data row4 col2" >Anapa Airport</td>
#       <td id="T_d5461_row4_col3" class="data row4 col3" >RU-KDA</td>
#       <td id="T_d5461_row4_col4" class="data row4 col4" >1</td>
#       <td id="T_d5461_row4_col5" class="data row4 col5" >45.002102</td>
#       <td id="T_d5461_row4_col6" class="data row4 col6" >37.347301</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Airports with the most runways:

# %%
?[code, city, desc, region, runways, lat, lon] := *airport{code, city, desc, region, runways, lat, lon}

:order -runways
:limit 10
# Out:
# <style type="text/css">
# #T_b20fa_row0_col0, #T_b20fa_row0_col1, #T_b20fa_row0_col2, #T_b20fa_row0_col3, #T_b20fa_row1_col0, #T_b20fa_row1_col1, #T_b20fa_row1_col2, #T_b20fa_row1_col3, #T_b20fa_row2_col0, #T_b20fa_row2_col1, #T_b20fa_row2_col2, #T_b20fa_row2_col3, #T_b20fa_row3_col0, #T_b20fa_row3_col1, #T_b20fa_row3_col2, #T_b20fa_row3_col3, #T_b20fa_row4_col0, #T_b20fa_row4_col1, #T_b20fa_row4_col2, #T_b20fa_row4_col3, #T_b20fa_row5_col0, #T_b20fa_row5_col1, #T_b20fa_row5_col2, #T_b20fa_row5_col3, #T_b20fa_row6_col0, #T_b20fa_row6_col1, #T_b20fa_row6_col2, #T_b20fa_row6_col3, #T_b20fa_row7_col0, #T_b20fa_row7_col1, #T_b20fa_row7_col2, #T_b20fa_row7_col3, #T_b20fa_row8_col0, #T_b20fa_row8_col1, #T_b20fa_row8_col2, #T_b20fa_row8_col3, #T_b20fa_row9_col0, #T_b20fa_row9_col1, #T_b20fa_row9_col2, #T_b20fa_row9_col3 {
#   color: black;
# }
# #T_b20fa_row0_col4, #T_b20fa_row0_col5, #T_b20fa_row0_col6, #T_b20fa_row1_col4, #T_b20fa_row1_col5, #T_b20fa_row1_col6, #T_b20fa_row2_col4, #T_b20fa_row2_col5, #T_b20fa_row2_col6, #T_b20fa_row3_col4, #T_b20fa_row3_col5, #T_b20fa_row3_col6, #T_b20fa_row4_col4, #T_b20fa_row4_col5, #T_b20fa_row4_col6, #T_b20fa_row5_col4, #T_b20fa_row5_col5, #T_b20fa_row5_col6, #T_b20fa_row6_col4, #T_b20fa_row6_col5, #T_b20fa_row6_col6, #T_b20fa_row7_col4, #T_b20fa_row7_col5, #T_b20fa_row7_col6, #T_b20fa_row8_col4, #T_b20fa_row8_col5, #T_b20fa_row8_col6, #T_b20fa_row9_col4, #T_b20fa_row9_col5, #T_b20fa_row9_col6 {
#   color: #307fc1;
# }
# </style>
# <table id="T_b20fa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b20fa_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_b20fa_level0_col1" class="col_heading level0 col1" >city</th>
#       <th id="T_b20fa_level0_col2" class="col_heading level0 col2" >desc</th>
#       <th id="T_b20fa_level0_col3" class="col_heading level0 col3" >region</th>
#       <th id="T_b20fa_level0_col4" class="col_heading level0 col4" >runways</th>
#       <th id="T_b20fa_level0_col5" class="col_heading level0 col5" >lat</th>
#       <th id="T_b20fa_level0_col6" class="col_heading level0 col6" >lon</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b20fa_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b20fa_row0_col0" class="data row0 col0" >DFW</td>
#       <td id="T_b20fa_row0_col1" class="data row0 col1" >Dallas</td>
#       <td id="T_b20fa_row0_col2" class="data row0 col2" >Dallas/Fort Worth International Airport</td>
#       <td id="T_b20fa_row0_col3" class="data row0 col3" >US-TX</td>
#       <td id="T_b20fa_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_b20fa_row0_col5" class="data row0 col5" >32.896801</td>
#       <td id="T_b20fa_row0_col6" class="data row0 col6" >-97.038002</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b20fa_row1_col0" class="data row1 col0" >ORD</td>
#       <td id="T_b20fa_row1_col1" class="data row1 col1" >Chicago</td>
#       <td id="T_b20fa_row1_col2" class="data row1 col2" >Chicago O'Hare International Airport</td>
#       <td id="T_b20fa_row1_col3" class="data row1 col3" >US-IL</td>
#       <td id="T_b20fa_row1_col4" class="data row1 col4" >7</td>
#       <td id="T_b20fa_row1_col5" class="data row1 col5" >41.978600</td>
#       <td id="T_b20fa_row1_col6" class="data row1 col6" >-87.904800</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b20fa_row2_col0" class="data row2 col0" >AMS</td>
#       <td id="T_b20fa_row2_col1" class="data row2 col1" >Amsterdam</td>
#       <td id="T_b20fa_row2_col2" class="data row2 col2" >Amsterdam Airport Schiphol</td>
#       <td id="T_b20fa_row2_col3" class="data row2 col3" >NL-NH</td>
#       <td id="T_b20fa_row2_col4" class="data row2 col4" >6</td>
#       <td id="T_b20fa_row2_col5" class="data row2 col5" >52.308601</td>
#       <td id="T_b20fa_row2_col6" class="data row2 col6" >4.763890</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b20fa_row3_col0" class="data row3 col0" >BOS</td>
#       <td id="T_b20fa_row3_col1" class="data row3 col1" >Boston</td>
#       <td id="T_b20fa_row3_col2" class="data row3 col2" >Boston Logan</td>
#       <td id="T_b20fa_row3_col3" class="data row3 col3" >US-MA</td>
#       <td id="T_b20fa_row3_col4" class="data row3 col4" >6</td>
#       <td id="T_b20fa_row3_col5" class="data row3 col5" >42.364300</td>
#       <td id="T_b20fa_row3_col6" class="data row3 col6" >-71.005203</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b20fa_row4_col0" class="data row4 col0" >DEN</td>
#       <td id="T_b20fa_row4_col1" class="data row4 col1" >Denver</td>
#       <td id="T_b20fa_row4_col2" class="data row4 col2" >Denver International Airport</td>
#       <td id="T_b20fa_row4_col3" class="data row4 col3" >US-CO</td>
#       <td id="T_b20fa_row4_col4" class="data row4 col4" >6</td>
#       <td id="T_b20fa_row4_col5" class="data row4 col5" >39.861698</td>
#       <td id="T_b20fa_row4_col6" class="data row4 col6" >-104.672997</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b20fa_row5_col0" class="data row5 col0" >DTW</td>
#       <td id="T_b20fa_row5_col1" class="data row5 col1" >Detroit</td>
#       <td id="T_b20fa_row5_col2" class="data row5 col2" >Detroit Metropolitan, Wayne County</td>
#       <td id="T_b20fa_row5_col3" class="data row5 col3" >US-MI</td>
#       <td id="T_b20fa_row5_col4" class="data row5 col4" >6</td>
#       <td id="T_b20fa_row5_col5" class="data row5 col5" >42.212399</td>
#       <td id="T_b20fa_row5_col6" class="data row5 col6" >-83.353401</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b20fa_row6_col0" class="data row6 col0" >ATL</td>
#       <td id="T_b20fa_row6_col1" class="data row6 col1" >Atlanta</td>
#       <td id="T_b20fa_row6_col2" class="data row6 col2" >Hartsfield - Jackson Atlanta International Airport</td>
#       <td id="T_b20fa_row6_col3" class="data row6 col3" >US-GA</td>
#       <td id="T_b20fa_row6_col4" class="data row6 col4" >5</td>
#       <td id="T_b20fa_row6_col5" class="data row6 col5" >33.636700</td>
#       <td id="T_b20fa_row6_col6" class="data row6 col6" >-84.428101</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b20fa_row7_col0" class="data row7 col0" >GIS</td>
#       <td id="T_b20fa_row7_col1" class="data row7 col1" >Gisborne</td>
#       <td id="T_b20fa_row7_col2" class="data row7 col2" >Gisborne Airport</td>
#       <td id="T_b20fa_row7_col3" class="data row7 col3" >NZ-GIS</td>
#       <td id="T_b20fa_row7_col4" class="data row7 col4" >5</td>
#       <td id="T_b20fa_row7_col5" class="data row7 col5" >-38.663300</td>
#       <td id="T_b20fa_row7_col6" class="data row7 col6" >177.977997</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b20fa_row8_col0" class="data row8 col0" >HLZ</td>
#       <td id="T_b20fa_row8_col1" class="data row8 col1" >Hamilton</td>
#       <td id="T_b20fa_row8_col2" class="data row8 col2" >Hamilton International Airport</td>
#       <td id="T_b20fa_row8_col3" class="data row8 col3" >NZ-WKO</td>
#       <td id="T_b20fa_row8_col4" class="data row8 col4" >5</td>
#       <td id="T_b20fa_row8_col5" class="data row8 col5" >-37.866699</td>
#       <td id="T_b20fa_row8_col6" class="data row8 col6" >175.332001</td>
#     </tr>
#     <tr>
#       <th id="T_b20fa_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b20fa_row9_col0" class="data row9 col0" >IAH</td>
#       <td id="T_b20fa_row9_col1" class="data row9 col1" >Houston</td>
#       <td id="T_b20fa_row9_col2" class="data row9 col2" >George Bush Intercontinental</td>
#       <td id="T_b20fa_row9_col3" class="data row9 col3" >US-TX</td>
#       <td id="T_b20fa_row9_col4" class="data row9 col4" >5</td>
#       <td id="T

# %% [markdown]
# How many airports are there in total?

# %%
?[count(code)] := *airport{code}
# Out:
# <style type="text/css">
# #T_cbe90_row0_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_cbe90">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cbe90_level0_col0" class="col_heading level0 col0" >count(code)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cbe90_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cbe90_row0_col0" class="data row0 col0" >3504</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's get a distribution of the initials of the airport codes:

# %%
?[count(initial), initial] := *airport{code}, initial = first(chars(code))

:order initial
# Out:
# <style type="text/css">
# #T_ca78b_row0_col0, #T_ca78b_row1_col0, #T_ca78b_row2_col0, #T_ca78b_row3_col0, #T_ca78b_row4_col0, #T_ca78b_row5_col0, #T_ca78b_row6_col0, #T_ca78b_row7_col0, #T_ca78b_row8_col0, #T_ca78b_row9_col0, #T_ca78b_row10_col0, #T_ca78b_row11_col0, #T_ca78b_row12_col0, #T_ca78b_row13_col0, #T_ca78b_row14_col0, #T_ca78b_row15_col0, #T_ca78b_row16_col0, #T_ca78b_row17_col0, #T_ca78b_row18_col0, #T_ca78b_row19_col0, #T_ca78b_row20_col0, #T_ca78b_row21_col0, #T_ca78b_row22_col0, #T_ca78b_row23_col0, #T_ca78b_row24_col0, #T_ca78b_row25_col0 {
#   color: #307fc1;
# }
# #T_ca78b_row0_col1, #T_ca78b_row1_col1, #T_ca78b_row2_col1, #T_ca78b_row3_col1, #T_ca78b_row4_col1, #T_ca78b_row5_col1, #T_ca78b_row6_col1, #T_ca78b_row7_col1, #T_ca78b_row8_col1, #T_ca78b_row9_col1, #T_ca78b_row10_col1, #T_ca78b_row11_col1, #T_ca78b_row12_col1, #T_ca78b_row13_col1, #T_ca78b_row14_col1, #T_ca78b_row15_col1, #T_ca78b_row16_col1, #T_ca78b_row17_col1, #T_ca78b_row18_col1, #T_ca78b_row19_col1, #T_ca78b_row20_col1, #T_ca78b_row21_col1, #T_ca78b_row22_col1, #T_ca78b_row23_col1, #T_ca78b_row24_col1, #T_ca78b_row25_col1 {
#   color: black;
# }
# </style>
# <table id="T_ca78b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ca78b_level0_col0" class="col_heading level0 col0" >count(initial)</th>
#       <th id="T_ca78b_level0_col1" class="col_heading level0 col1" >initial</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ca78b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ca78b_row0_col0" class="data row0 col0" >212</td>
#       <td id="T_ca78b_row0_col1" class="data row0 col1" >A</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ca78b_row1_col0" class="data row1 col0" >235</td>
#       <td id="T_ca78b_row1_col1" class="data row1 col1" >B</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ca78b_row2_col0" class="data row2 col0" >214</td>
#       <td id="T_ca78b_row2_col1" class="data row2 col1" >C</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ca78b_row3_col0" class="data row3 col0" >116</td>
#       <td id="T_ca78b_row3_col1" class="data row3 col1" >D</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ca78b_row4_col0" class="data row4 col0" >95</td>
#       <td id="T_ca78b_row4_col1" class="data row4 col1" >E</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ca78b_row5_col0" class="data row5 col0" >76</td>
#       <td id="T_ca78b_row5_col1" class="data row5 col1" >F</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ca78b_row6_col0" class="data row6 col0" >135</td>
#       <td id="T_ca78b_row6_col1" class="data row6 col1" >G</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ca78b_row7_col0" class="data row7 col0" >129</td>
#       <td id="T_ca78b_row7_col1" class="data row7 col1" >H</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ca78b_row8_col0" class="data row8 col0" >112</td>
#       <td id="T_ca78b_row8_col1" class="data row8 col1" >I</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ca78b_row9_col0" class="data row9 col0" >80</td>
#       <td id="T_ca78b_row9_col1" class="data row9 col1" >J</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ca78b_row10_col0" class="data row10 col0" >197</td>
#       <td id="T_ca78b_row10_col1" class="data row10 col1" >K</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ca78b_row11_col0" class="data row11 col0" >184</td>
#       <td id="T_ca78b_row11_col1" class="data row11 col1" >L</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ca78b_row12_col0" class="data row12 col0" >228</td>
#       <td id="T_ca78b_row12_col1" class="data row12 col1" >M</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ca78b_row13_col0" class="data row13 col0" >111</td>
#       <td id="T_ca78b_row13_col1" class="data row13 col1" >N</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ca78b_row14_col0" class="data row14 col0" >89</td>
#       <td id="T_ca78b_row14_col1" class="data row14 col1" >O</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ca78b_row15_col0" class="data row15 col0" >203</td>
#       <td id="T_ca78b_row15_col1" class="data row15 col1" >P</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ca78b_row16_col0" class="data row16 col0" >7</td>
#       <td id="T_ca78b_row16_col1" class="data row16 col1" >Q</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ca78b_row17_col0" class="data row17 col0" >121</td>
#       <td id="T_ca78b_row17_col1" class="data row17 col1" >R</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ca78b_row18_col0" class="data row18 col0" >245</td>
#       <td id="T_ca78b_row18_col1" class="data row18 col1" >S</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ca78b_row19_col0" class="data row19 col0" >205</td>
#       <td id="T_ca78b_row19_col1" class="data row19 col1" >T</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ca78b_row20_col0" class="data row20 col0" >77</td>
#       <td id="T_ca78b_row20_col1" class="data row20 col1" >U</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ca78b_row21_col0" class="data row21 col0" >86</td>
#       <td id="T_ca78b_row21_col1" class="data row21 col1" >V</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ca78b_row22_col0" class="data row22 col0" >59</td>
#       <td id="T_ca78b_row22_col1" class="data row22 col1" >W</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ca78b_row23_col0" class="data row23 col0" >28</td>
#       <td id="T_ca78b_row23_col1" class="data row23 col1" >X</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ca78b_row24_col0" class="data row24 col0" >211</td>
#       <td id="T_ca78b_row24_col1" class="data row24 col1" >Y</td>
#     </tr>
#     <tr>
#       <th id="T_ca78b_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_ca78b_row25_col0" class="data row25 col0" >49</td>
#       <td id="T_ca78b_row25_col1" class="data row25 col1" >Z</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# More useful are the statistics of runways:

# %%
?[count(r), count_unique(r), sum(r), min(r), max(r), mean(r), std_dev(r)] := 
    *airport{runways: r}
# Out:
# <style type="text/css">
# #T_ad18f_row0_col0, #T_ad18f_row0_col1, #T_ad18f_row0_col2, #T_ad18f_row0_col3, #T_ad18f_row0_col4, #T_ad18f_row0_col5, #T_ad18f_row0_col6 {
#   color: #307fc1;
# }
# </style>
# <table id="T_ad18f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad18f_level0_col0" class="col_heading level0 col0" >count(r)</th>
#       <th id="T_ad18f_level0_col1" class="col_heading level0 col1" >count_unique(r)</th>
#       <th id="T_ad18f_level0_col2" class="col_heading level0 col2" >sum(r)</th>
#       <th id="T_ad18f_level0_col3" class="col_heading level0 col3" >min(r)</th>
#       <th id="T_ad18f_level0_col4" class="col_heading level0 col4" >max(r)</th>
#       <th id="T_ad18f_level0_col5" class="col_heading level0 col5" >mean(r)</th>
#       <th id="T_ad18f_level0_col6" class="col_heading level0 col6" >std_dev(r)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad18f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad18f_row0_col0" class="data row0 col0" >3504</td>
#       <td id="T_ad18f_row0_col1" class="data row0 col1" >7</td>
#       <td id="T_ad18f_row0_col2" class="data row0 col2" >4980.000000</td>
#       <td id="T_ad18f_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_ad18f_row0_col4" class="data row0 col4" >7</td>
#       <td id="T_ad18f_row0_col5" class="data row0 col5" >1.421233</td>
#       <td id="T_ad18f_row0_col6" class="data row0 col6" >0.743083</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Using `country`, we can find countries with no airports:

# %%
?[desc] := *country{code, desc}, not *airport{country: code}
# Out:
# <style type="text/css">
# #T_d5d37_row0_col0, #T_d5d37_row1_col0, #T_d5d37_row2_col0, #T_d5d37_row3_col0, #T_d5d37_row4_col0 {
#   color: black;
# }
# </style>
# <table id="T_d5d37">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d5d37_level0_col0" class="col_heading level0 col0" >desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d5d37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d5d37_row0_col0" class="data row0 col0" >Andorra</td>
#     </tr>
#     <tr>
#       <th id="T_d5d37_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d5d37_row1_col0" class="data row1 col0" >Liechtenstein</td>
#     </tr>
#     <tr>
#       <th id="T_d5d37_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d5d37_row2_col0" class="data row2 col0" >Monaco</td>
#     </tr>
#     <tr>
#       <th id="T_d5d37_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d5d37_row3_col0" class="data row3 col0" >Pitcairn</td>
#     </tr>
#     <tr>
#       <th id="T_d5d37_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d5d37_row4_col0" class="data row4 col0" >San Marino</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `route` relation by itself is rather boring:

# %%
?[fr, to, dist] := *route{fr, to, dist}

:limit 10
# Out:
# <style type="text/css">
# #T_fd79a_row0_col0, #T_fd79a_row0_col1, #T_fd79a_row1_col0, #T_fd79a_row1_col1, #T_fd79a_row2_col0, #T_fd79a_row2_col1, #T_fd79a_row3_col0, #T_fd79a_row3_col1, #T_fd79a_row4_col0, #T_fd79a_row4_col1, #T_fd79a_row5_col0, #T_fd79a_row5_col1, #T_fd79a_row6_col0, #T_fd79a_row6_col1, #T_fd79a_row7_col0, #T_fd79a_row7_col1, #T_fd79a_row8_col0, #T_fd79a_row8_col1, #T_fd79a_row9_col0, #T_fd79a_row9_col1 {
#   color: black;
# }
# #T_fd79a_row0_col2, #T_fd79a_row1_col2, #T_fd79a_row2_col2, #T_fd79a_row3_col2, #T_fd79a_row4_col2, #T_fd79a_row5_col2, #T_fd79a_row6_col2, #T_fd79a_row7_col2, #T_fd79a_row8_col2, #T_fd79a_row9_col2 {
#   color: #307fc1;
# }
# </style>
# <table id="T_fd79a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fd79a_level0_col0" class="col_heading level0 col0" >fr</th>
#       <th id="T_fd79a_level0_col1" class="col_heading level0 col1" >to</th>
#       <th id="T_fd79a_level0_col2" class="col_heading level0 col2" >dist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd79a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fd79a_row0_col0" class="data row0 col0" >AAA</td>
#       <td id="T_fd79a_row0_col1" class="data row0 col1" >FAC</td>
#       <td id="T_fd79a_row0_col2" class="data row0 col2" >48.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fd79a_row1_col0" class="data row1 col0" >AAA</td>
#       <td id="T_fd79a_row1_col1" class="data row1 col1" >MKP</td>
#       <td id="T_fd79a_row1_col2" class="data row1 col2" >133.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fd79a_row2_col0" class="data row2 col0" >AAA</td>
#       <td id="T_fd79a_row2_col1" class="data row2 col1" >PPT</td>
#       <td id="T_fd79a_row2_col2" class="data row2 col2" >270.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fd79a_row3_col0" class="data row3 col0" >AAA</td>
#       <td id="T_fd79a_row3_col1" class="data row3 col1" >RAR</td>
#       <td id="T_fd79a_row3_col2" class="data row3 col2" >968.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fd79a_row4_col0" class="data row4 col0" >AAE</td>
#       <td id="T_fd79a_row4_col1" class="data row4 col1" >ALG</td>
#       <td id="T_fd79a_row4_col2" class="data row4 col2" >254.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fd79a_row5_col0" class="data row5 col0" >AAE</td>
#       <td id="T_fd79a_row5_col1" class="data row5 col1" >CDG</td>
#       <td id="T_fd79a_row5_col2" class="data row5 col2" >882.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fd79a_row6_col0" class="data row6 col0" >AAE</td>
#       <td id="T_fd79a_row6_col1" class="data row6 col1" >IST</td>
#       <td id="T_fd79a_row6_col2" class="data row6 col2" >1161.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fd79a_row7_col0" class="data row7 col0" >AAE</td>
#       <td id="T_fd79a_row7_col1" class="data row7 col1" >LYS</td>
#       <td id="T_fd79a_row7_col2" class="data row7 col2" >631.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fd79a_row8_col0" class="data row8 col0" >AAE</td>
#       <td id="T_fd79a_row8_col1" class="data row8 col1" >MRS</td>
#       <td id="T_fd79a_row8_col2" class="data row8 col2" >477.000000</td>
#     </tr>
#     <tr>
#       <th id="T_fd79a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fd79a_row9_col0" class="data row9 col0" >AAE</td>
#       <td id="T_fd79a_row9_col1" class="data row9 col1" >ORN</td>
#       <td id="T_fd79a_row9_col2" class="data row9 col2" >477.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# It just records the starting and ending airports of each route, together with the distance. This relation only becomes useful when used as a graph.
#
# Airports with no routes:

# %%
?[code, desc] := *airport{code, desc}, not *route{fr: code}, not *route{to: code}
# Out:
# <style type="text/css">
# #T_35993_row0_col0, #T_35993_row0_col1, #T_35993_row1_col0, #T_35993_row1_col1, #T_35993_row2_col0, #T_35993_row2_col1, #T_35993_row3_col0, #T_35993_row3_col1, #T_35993_row4_col0, #T_35993_row4_col1, #T_35993_row5_col0, #T_35993_row5_col1, #T_35993_row6_col0, #T_35993_row6_col1, #T_35993_row7_col0, #T_35993_row7_col1, #T_35993_row8_col0, #T_35993_row8_col1, #T_35993_row9_col0, #T_35993_row9_col1, #T_35993_row10_col0, #T_35993_row10_col1, #T_35993_row11_col0, #T_35993_row11_col1, #T_35993_row12_col0, #T_35993_row12_col1, #T_35993_row13_col0, #T_35993_row13_col1, #T_35993_row14_col0, #T_35993_row14_col1, #T_35993_row15_col0, #T_35993_row15_col1, #T_35993_row16_col0, #T_35993_row16_col1, #T_35993_row17_col0, #T_35993_row17_col1, #T_35993_row18_col0, #T_35993_row18_col1, #T_35993_row19_col0, #T_35993_row19_col1, #T_35993_row20_col0, #T_35993_row20_col1, #T_35993_row21_col0, #T_35993_row21_col1, #T_35993_row22_col0, #T_35993_row22_col1, #T_35993_row23_col0, #T_35993_row23_col1, #T_35993_row24_col0, #T_35993_row24_col1, #T_35993_row25_col0, #T_35993_row25_col1, #T_35993_row26_col0, #T_35993_row26_col1, #T_35993_row27_col0, #T_35993_row27_col1 {
#   color: black;
# }
# </style>
# <table id="T_35993">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_35993_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_35993_level0_col1" class="col_heading level0 col1" >desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_35993_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_35993_row0_col0" class="data row0 col0" >AFW</td>
#       <td id="T_35993_row0_col1" class="data row0 col1" >Fort Worth Alliance Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_35993_row1_col0" class="data row1 col0" >APA</td>
#       <td id="T_35993_row1_col1" class="data row1 col1" >Centennial Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_35993_row2_col0" class="data row2 col0" >APK</td>
#       <td id="T_35993_row2_col1" class="data row2 col1" >Apataki Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_35993_row3_col0" class="data row3 col0" >BID</td>
#       <td id="T_35993_row3_col1" class="data row3 col1" >Block Island State Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_35993_row4_col0" class="data row4 col0" >BVS</td>
#       <td id="T_35993_row4_col1" class="data row4 col1" >Breves Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_35993_row5_col0" class="data row5 col0" >BWU</td>
#       <td id="T_35993_row5_col1" class="data row5 col1" >Sydney Bankstown Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_35993_row6_col0" class="data row6 col0" >CRC</td>
#       <td id="T_35993_row6_col1" class="data row6 col1" >Santa Ana Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_35993_row7_col0" class="data row7 col0" >CVT</td>
#       <td id="T_35993_row7_col1" class="data row7 col1" >Coventry Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_35993_row8_col0" class="data row8 col0" >EKA</td>
#       <td id="T_35993_row8_col1" class="data row8 col1" >Murray Field</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_35993_row9_col0" class="data row9 col0" >GYZ</td>
#       <td id="T_35993_row9_col1" class="data row9 col1" >Gruyere Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_35993_row10_col0" class="data row10 col0" >HFN</td>
#       <td id="T_35993_row10_col1" class="data row10 col1" >Hornafjordur Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_35993_row11_col0" class="data row11 col0" >HZK</td>
#       <td id="T_35993_row11_col1" class="data row11 col1" >Husavik Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_35993_row12_col0" class="data row12 col0" >ILG</td>
#       <td id="T_35993_row12_col1" class="data row12 col1" >New Castle Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_35993_row13_col0" class="data row13 col0" >INT</td>
#       <td id="T_35993_row13_col1" class="data row13 col1" >Smith Reynolds Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_35993_row14_col0" class="data row14 col0" >ISL</td>
#       <td id="T_35993_row14_col1" class="data row14 col1" >Ataturk International Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_35993_row15_col0" class="data row15 col0" >KGG</td>
#       <td id="T_35993_row15_col1" class="data row15 col1" >Kédougou Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_35993_row16_col0" class="data row16 col0" >NBW</td>
#       <td id="T_35993_row16_col1" class="data row16 col1" >Leeward Point Field</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_35993_row17_col0" class="data row17 col0" >NFO</td>
#       <td id="T_35993_row17_col1" class="data row17 col1" >Mata'aho Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_35993_row18_col0" class="data row18 col0" >PSY</td>
#       <td id="T_35993_row18_col1" class="data row18 col1" >Stanley Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_35993_row19_col0" class="data row19 col0" >RIG</td>
#       <td id="T_35993_row19_col1" class="data row19 col1" >Rio Grande Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_35993_row20_col0" class="data row20 col0" >SFD</td>
#       <td id="T_35993_row20_col1" class="data row20 col1" >San Fernando De Apure Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_35993_row21_col0" class="data row21 col0" >SFH</td>
#       <td id="T_35993_row21_col1" class="data row21 col1" >San Felipe International Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_35993_row22_col0" class="data row22 col0" >SXF</td>
#       <td id="T_35993_row22_col1" class="data row22 col1" >Berlin-Schönefeld International Airport *Closed*</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_35993_row23_col0" class="data row23 col0" >TUA</td>
#       <td id="T_35993_row23_col1" class="data row23 col1" >Teniente Coronel Luis a Mantilla Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_35993_row24_col0" class="data row24 col0" >TWB</td>
#       <td id="T_35993_row24_col1" class="data row24 col1" >Toowoomba Airport</td>
#     </tr>
#     <tr>
#       <th id="T_35993_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_35993_row25_col0" class="data row25 col0" >TXL</td>
#       <td id="T_35993_row25_col1" class="data row25 col1" >Berlin, Tegel International Airport *Closed*</td>
#     </tr>
#     <tr>
#       <th id="T_3599

# %% [markdown]
# Airports with the most out routes:

# %%
route_count[fr, count(fr)] := *route{fr}
?[code, n] := route_count[code, n]

:sort -n
:limit 5
# Out:
# <style type="text/css">
# #T_d6cbc_row0_col0, #T_d6cbc_row1_col0, #T_d6cbc_row2_col0, #T_d6cbc_row3_col0, #T_d6cbc_row4_col0 {
#   color: black;
# }
# #T_d6cbc_row0_col1, #T_d6cbc_row1_col1, #T_d6cbc_row2_col1, #T_d6cbc_row3_col1, #T_d6cbc_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_d6cbc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6cbc_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_d6cbc_level0_col1" class="col_heading level0 col1" >n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6cbc_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d6cbc_row0_col0" class="data row0 col0" >FRA</td>
#       <td id="T_d6cbc_row0_col1" class="data row0 col1" >310</td>
#     </tr>
#     <tr>
#       <th id="T_d6cbc_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d6cbc_row1_col0" class="data row1 col0" >IST</td>
#       <td id="T_d6cbc_row1_col1" class="data row1 col1" >309</td>
#     </tr>
#     <tr>
#       <th id="T_d6cbc_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d6cbc_row2_col0" class="data row2 col0" >CDG</td>
#       <td id="T_d6cbc_row2_col1" class="data row2 col1" >293</td>
#     </tr>
#     <tr>
#       <th id="T_d6cbc_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d6cbc_row3_col0" class="data row3 col0" >AMS</td>
#       <td id="T_d6cbc_row3_col1" class="data row3 col1" >283</td>
#     </tr>
#     <tr>
#       <th id="T_d6cbc_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d6cbc_row4_col0" class="data row4 col0" >MUC</td>
#       <td id="T_d6cbc_row4_col1" class="data row4 col1" >270</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# How many routes are there from the European Union to the US?

# %%
routes[unique(r)] := *contain['EU', fr],
                     *route{fr, to},
                     *airport{code: to, country: 'US'},
                     r = [fr, to]
?[n] := routes[rs], n = length(rs)
# Out:
# <style type="text/css">
# #T_85605_row0_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_85605">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_85605_level0_col0" class="col_heading level0 col0" >n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_85605_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_85605_row0_col0" class="data row0 col0" >435</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# How many airports are there in the US with routes from the EU?

# %%
?[count_unique(to)] := *contain['EU', fr],
                       *route{fr, to},
                       *airport{code: to, country: 'US'}
# Out:
# <style type="text/css">
# #T_7c0b4_row0_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_7c0b4">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7c0b4_level0_col0" class="col_heading level0 col0" >count_unique(to)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c0b4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7c0b4_row0_col0" class="data row0 col0" >45</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# How many routes are there for each airport in London, UK?

# %%
?[code, count(code)] := *airport{code, city: 'London', region: 'GB-ENG'}, *route{fr: code}
# Out:
# <style type="text/css">
# #T_dfae5_row0_col0, #T_dfae5_row1_col0, #T_dfae5_row2_col0, #T_dfae5_row3_col0, #T_dfae5_row4_col0 {
#   color: black;
# }
# #T_dfae5_row0_col1, #T_dfae5_row1_col1, #T_dfae5_row2_col1, #T_dfae5_row3_col1, #T_dfae5_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_dfae5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfae5_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_dfae5_level0_col1" class="col_heading level0 col1" >count(code)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfae5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfae5_row0_col0" class="data row0 col0" >LCY</td>
#       <td id="T_dfae5_row0_col1" class="data row0 col1" >51</td>
#     </tr>
#     <tr>
#       <th id="T_dfae5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfae5_row1_col0" class="data row1 col0" >LGW</td>
#       <td id="T_dfae5_row1_col1" class="data row1 col1" >232</td>
#     </tr>
#     <tr>
#       <th id="T_dfae5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfae5_row2_col0" class="data row2 col0" >LHR</td>
#       <td id="T_dfae5_row2_col1" class="data row2 col1" >221</td>
#     </tr>
#     <tr>
#       <th id="T_dfae5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfae5_row3_col0" class="data row3 col0" >LTN</td>
#       <td id="T_dfae5_row3_col1" class="data row3 col1" >130</td>
#     </tr>
#     <tr>
#       <th id="T_dfae5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dfae5_row4_col0" class="data row4 col0" >STN</td>
#       <td id="T_dfae5_row4_col1" class="data row4 col1" >211</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We need to specify the region, because there is another city called London, not in the UK.
#
# How many airports are reachable from London, UK in two hops?

# %%
lon_uk_airports[code] := *airport{code, city: 'London', region: 'GB-ENG'}
one_hop[to] := lon_uk_airports[fr], *route{fr, to}, not lon_uk_airports[to];
?[count_unique(a3)] := one_hop[a2], *route{fr: a2, to: a3}, not lon_uk_airports[a3];
# Out:
# <style type="text/css">
# #T_743f7_row0_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_743f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_743f7_level0_col0" class="col_heading level0 col0" >count_unique(a3)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_743f7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_743f7_row0_col0" class="data row0 col0" >2353</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# What are the cities directly reachable from LGW (London Gatwick), but furthermost away?

# %%
?[city, dist] := *route{fr: 'LGW', to, dist},
                 *airport{code: to, city}
:order -dist
:limit 10
# Out:
# <style type="text/css">
# #T_7eff1_row0_col0, #T_7eff1_row1_col0, #T_7eff1_row2_col0, #T_7eff1_row3_col0, #T_7eff1_row4_col0, #T_7eff1_row5_col0, #T_7eff1_row6_col0, #T_7eff1_row7_col0, #T_7eff1_row8_col0, #T_7eff1_row9_col0 {
#   color: black;
# }
# #T_7eff1_row0_col1, #T_7eff1_row1_col1, #T_7eff1_row2_col1, #T_7eff1_row3_col1, #T_7eff1_row4_col1, #T_7eff1_row5_col1, #T_7eff1_row6_col1, #T_7eff1_row7_col1, #T_7eff1_row8_col1, #T_7eff1_row9_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_7eff1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7eff1_level0_col0" class="col_heading level0 col0" >city</th>
#       <th id="T_7eff1_level0_col1" class="col_heading level0 col1" >dist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7eff1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7eff1_row0_col0" class="data row0 col0" >Buenos Aires</td>
#       <td id="T_7eff1_row0_col1" class="data row0 col1" >6908.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7eff1_row1_col0" class="data row1 col0" >Singapore</td>
#       <td id="T_7eff1_row1_col1" class="data row1 col1" >6751.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7eff1_row2_col0" class="data row2 col0" >Langkawi</td>
#       <td id="T_7eff1_row2_col1" class="data row2 col1" >6299.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7eff1_row3_col0" class="data row3 col0" >Duong Dong</td>
#       <td id="T_7eff1_row3_col1" class="data row3 col1" >6264.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7eff1_row4_col0" class="data row4 col0" >Taipei</td>
#       <td id="T_7eff1_row4_col1" class="data row4 col1" >6080.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7eff1_row5_col0" class="data row5 col0" >Port Louis</td>
#       <td id="T_7eff1_row5_col1" class="data row5 col1" >6053.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7eff1_row6_col0" class="data row6 col0" >Rayong</td>
#       <td id="T_7eff1_row6_col1" class="data row6 col1" >6008.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7eff1_row7_col0" class="data row7 col0" >Cape Town</td>
#       <td id="T_7eff1_row7_col1" class="data row7 col1" >5987.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7eff1_row8_col0" class="data row8 col0" >Hong Kong</td>
#       <td id="T_7eff1_row8_col1" class="data row8 col1" >5982.000000</td>
#     </tr>
#     <tr>
#       <th id="T_7eff1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7eff1_row9_col0" class="data row9 col0" >Shanghai</td>
#       <td id="T_7eff1_row9_col1" class="data row9 col1" >5745.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# What airports are within 0.1 degrees of the Greenwich meridian?

# %%
?[code, desc, lon, lat] := *airport{lon, lat, code, desc}, lon > -0.1, lon < 0.1
# Out:
# <style type="text/css">
# #T_33b8d_row0_col0, #T_33b8d_row0_col1, #T_33b8d_row1_col0, #T_33b8d_row1_col1, #T_33b8d_row2_col0, #T_33b8d_row2_col1, #T_33b8d_row3_col0, #T_33b8d_row3_col1 {
#   color: black;
# }
# #T_33b8d_row0_col2, #T_33b8d_row0_col3, #T_33b8d_row1_col2, #T_33b8d_row1_col3, #T_33b8d_row2_col2, #T_33b8d_row2_col3, #T_33b8d_row3_col2, #T_33b8d_row3_col3 {
#   color: #307fc1;
# }
# </style>
# <table id="T_33b8d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_33b8d_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_33b8d_level0_col1" class="col_heading level0 col1" >desc</th>
#       <th id="T_33b8d_level0_col2" class="col_heading level0 col2" >lon</th>
#       <th id="T_33b8d_level0_col3" class="col_heading level0 col3" >lat</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33b8d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_33b8d_row0_col0" class="data row0 col0" >CDT</td>
#       <td id="T_33b8d_row0_col1" class="data row0 col1" >Castellon De La Plana Airport</td>
#       <td id="T_33b8d_row0_col2" class="data row0 col2" >0.026111</td>
#       <td id="T_33b8d_row0_col3" class="data row0 col3" >39.999199</td>
#     </tr>
#     <tr>
#       <th id="T_33b8d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_33b8d_row1_col0" class="data row1 col0" >LCY</td>
#       <td id="T_33b8d_row1_col1" class="data row1 col1" >London City Airport</td>
#       <td id="T_33b8d_row1_col2" class="data row1 col2" >0.055278</td>
#       <td id="T_33b8d_row1_col3" class="data row1 col3" >51.505278</td>
#     </tr>
#     <tr>
#       <th id="T_33b8d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_33b8d_row2_col0" class="data row2 col0" >LDE</td>
#       <td id="T_33b8d_row2_col1" class="data row2 col1" >Tarbes-Lourdes-Pyrénées Airport</td>
#       <td id="T_33b8d_row2_col2" class="data row2 col2" >-0.006439</td>
#       <td id="T_33b8d_row2_col3" class="data row2 col3" >43.178699</td>
#     </tr>
#     <tr>
#       <th id="T_33b8d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_33b8d_row3_col0" class="data row3 col0" >LEH</td>
#       <td id="T_33b8d_row3_col1" class="data row3 col1" >Le Havre Octeville Airport</td>
#       <td id="T_33b8d_row3_col2" class="data row3 col2" >0.088056</td>
#       <td id="T_33b8d_row3_col3" class="data row3 col3" >49.533901</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Airports in a box drawn around London Heathrow, UK:

# %%
h_box[lon, lat] := *airport{code: 'LHR', lon, lat}
?[code, desc] := h_box[lhr_lon, lhr_lat], *airport{code, lon, lat, desc},
                 abs(lhr_lon - lon) < 1, abs(lhr_lat - lat) < 1
# Out:
# <style type="text/css">
# #T_8c623_row0_col0, #T_8c623_row0_col1, #T_8c623_row1_col0, #T_8c623_row1_col1, #T_8c623_row2_col0, #T_8c623_row2_col1, #T_8c623_row3_col0, #T_8c623_row3_col1, #T_8c623_row4_col0, #T_8c623_row4_col1, #T_8c623_row5_col0, #T_8c623_row5_col1 {
#   color: black;
# }
# </style>
# <table id="T_8c623">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c623_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_8c623_level0_col1" class="col_heading level0 col1" >desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c623_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c623_row0_col0" class="data row0 col0" >LCY</td>
#       <td id="T_8c623_row0_col1" class="data row0 col1" >London City Airport</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8c623_row1_col0" class="data row1 col0" >LGW</td>
#       <td id="T_8c623_row1_col1" class="data row1 col1" >London Gatwick</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_8c623_row2_col0" class="data row2 col0" >LHR</td>
#       <td id="T_8c623_row2_col1" class="data row2 col1" >London Heathrow</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_8c623_row3_col0" class="data row3 col0" >LTN</td>
#       <td id="T_8c623_row3_col1" class="data row3 col1" >London Luton Airport</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_8c623_row4_col0" class="data row4 col0" >SOU</td>
#       <td id="T_8c623_row4_col1" class="data row4 col1" >Southampton Airport</td>
#     </tr>
#     <tr>
#       <th id="T_8c623_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_8c623_row5_col0" class="data row5 col0" >STN</td>
#       <td id="T_8c623_row5_col1" class="data row5 col1" >London Stansted Airport</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For some spherical geometry: what is the angle subtended by SFO and NRT on the surface of the earth?

# %%
?[deg_diff] := *airport{code: 'SFO', lat: a_lat, lon: a_lon},
               *airport{code: 'NRT', lat: b_lat, lon: b_lon},
               deg_diff = rad_to_deg(haversine_deg_input(a_lat, a_lon, b_lat, b_lon))
# Out:
# <style type="text/css">
# #T_ebdcb_row0_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_ebdcb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ebdcb_level0_col0" class="col_heading level0 col0" >deg_diff</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ebdcb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ebdcb_row0_col0" class="data row0 col0" >73.992112</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We mentioned before that aggregations in Cozo are powerful. They are powerful because they can be used in recursions (some restrictions apply).
#
# Let's find the distance of the _shortest route_ between two airports. One wayis to enumerate all the routes between the two airports, and then apply `min` aggregation to the results. This cannot be implemented as stated, since the routes may contain cycles and hence there can be an infinite number of routes between two airports.
#
# Instead, think recursively. If we already have all the shortest routes between all nodes, we derive an _equation_ satisfied by the shortest route: the shortest route between `a` and `b` is either the distance of a direct route, or the sum of the shortest distance from `a` to `c` and the distance of a direct route from `c` to `d`. We apply our `min` aggregation to this recursive set instead.
#
# Write it out and it works. For exmaple, the shortest routes between the airports `LHR` and `YPO`:

# %%
shortest[b, min(dist)] := *route{fr: 'LHR', to: b, dist} 
                          # Start with the airport 'LHR', retrieve a direct route from 'LHR' to b

shortest[b, min(dist)] := shortest[c, d1], # Start with an existing shortest route from 'LHR' to c
                          *route{fr: c, to: b, dist: d2},  # Retrieve a direct route from c to b
                          dist = d1 + d2 # Add the distances

?[dist] := shortest['YPO', dist] # Extract the answer for 'YPO'. 
                                 # We chose it since it is the hardest airport to get to from 'LHR'.
# Out:
# <style type="text/css">
# #T_b18c2_row0_col0 {
#   color: #307fc1;
# }
# </style>
# <table id="T_b18c2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b18c2_level0_col0" class="col_heading level0 col0" >dist</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b18c2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b18c2_row0_col0" class="data row0 col0" >4147.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There is a caveat when you try to write similar queries. Say you try to write it in the following way (don't try to run it):
#
# ```python
# shortest[a, b, min(dist)] := *route{fr: a, to: b, dist}
# shortest[a, b, min(dist)] := shortest[a, c, d1],
#                           *route{fr: c, to: b, dist: d2},
#                           dist = d1 + d2
#
# ?[dist] := shortest['LHR', 'YPO', dist]
# ```
#
# You will find that the query does not complete in a reasonable amount of time, despite it being equivalent to the original query. Why?
#
# In the changed query, you are asking the database to compute the all-pair shortest path, and then extract the answer to a particular shortest path. Normally Cozo would apply a technique called _magic set rewrite_ so that only the needed answer would be calculated. However, in the changed query the presence of the aggregation operator `min` prevents that. In this case, applying the rewrite to the variable `a` would still yield the correct answer, but rewriting in any other way would give complete nonsense, and in the more general case with recursive aggregations this is a can of worms.
#
# So as explained in the [chapter about execution](execution.rst), magic set rewrites are only applied to rules without aggregations or recursions for the moment, until we are sure of the exact conditions under which the rewrites are safe. So for now at least the database executes the query as written, computing the result of the `shortest` rule containing more than ten million rows (to be exact, 3700 * 3700 = 13,690,000 rows) first!
#
# The bottom line is, be mindful of the cardinality of the return sets of recursive rules.

# %% [markdown]
# ### A tour of graph algorithms
#
# Now let's investigate the graph using some graph algorithms.
# As we have mentioned before, the Cozo running in browsers through WASM does not have
# the graph algorithms module enabled, so to run the following examples you will
# need to use some other implementation (for example, [the Python one](https://github.com/cozodb/pycozo)).
#
# Since path-finding is such a common operation on graphs, Cozo has several fixed rules for that:

# %%
starting[] <- [['LHR']]
goal[] <- [['YPO']]
?[starting, goal, distance, path] <~ ShortestPathDijkstra(*route[], starting[], goal[])
# Out:
# <style type="text/css">
# #T_9aaff_row0_col0, #T_9aaff_row0_col1 {
#   color: black;
# }
# #T_9aaff_row0_col2 {
#   color: #307fc1;
# }
# #T_9aaff_row0_col3 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_9aaff">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9aaff_level0_col0" class="col_heading level0 col0" >starting</th>
#       <th id="T_9aaff_level0_col1" class="col_heading level0 col1" >goal</th>
#       <th id="T_9aaff_level0_col2" class="col_heading level0 col2" >distance</th>
#       <th id="T_9aaff_level0_col3" class="col_heading level0 col3" >path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9aaff_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9aaff_row0_col0" class="data row0 col0" >LHR</td>
#       <td id="T_9aaff_row0_col1" class="data row0 col1" >YPO</td>
#       <td id="T_9aaff_row0_col2" class="data row0 col2" >4147.000000</td>
#       <td id="T_9aaff_row0_col3" class="data row0 col3" >['LHR', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Not only is it more efficient, but we also get a path for the shortest route.
#
# Not content with the shortest path, the following calculates ten the shortest paths:

# %%
starting[] <- [['LHR']]
goal[] <- [['YPO']]
?[starting, goal, distance, path] <~ KShortestPathYen(*route[], starting[], goal[], k: 10)
# Out:
# <style type="text/css">
# #T_7ab81_row0_col0, #T_7ab81_row0_col1, #T_7ab81_row1_col0, #T_7ab81_row1_col1, #T_7ab81_row2_col0, #T_7ab81_row2_col1, #T_7ab81_row3_col0, #T_7ab81_row3_col1, #T_7ab81_row4_col0, #T_7ab81_row4_col1, #T_7ab81_row5_col0, #T_7ab81_row5_col1, #T_7ab81_row6_col0, #T_7ab81_row6_col1, #T_7ab81_row7_col0, #T_7ab81_row7_col1, #T_7ab81_row8_col0, #T_7ab81_row8_col1, #T_7ab81_row9_col0, #T_7ab81_row9_col1 {
#   color: black;
# }
# #T_7ab81_row0_col2, #T_7ab81_row1_col2, #T_7ab81_row2_col2, #T_7ab81_row3_col2, #T_7ab81_row4_col2, #T_7ab81_row5_col2, #T_7ab81_row6_col2, #T_7ab81_row7_col2, #T_7ab81_row8_col2, #T_7ab81_row9_col2 {
#   color: #307fc1;
# }
# #T_7ab81_row0_col3, #T_7ab81_row1_col3, #T_7ab81_row2_col3, #T_7ab81_row3_col3, #T_7ab81_row4_col3, #T_7ab81_row5_col3, #T_7ab81_row6_col3, #T_7ab81_row7_col3, #T_7ab81_row8_col3, #T_7ab81_row9_col3 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_7ab81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7ab81_level0_col0" class="col_heading level0 col0" >starting</th>
#       <th id="T_7ab81_level0_col1" class="col_heading level0 col1" >goal</th>
#       <th id="T_7ab81_level0_col2" class="col_heading level0 col2" >distance</th>
#       <th id="T_7ab81_level0_col3" class="col_heading level0 col3" >path</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7ab81_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7ab81_row0_col0" class="data row0 col0" >LHR</td>
#       <td id="T_7ab81_row0_col1" class="data row0 col1" >YPO</td>
#       <td id="T_7ab81_row0_col2" class="data row0 col2" >4147.000000</td>
#       <td id="T_7ab81_row0_col3" class="data row0 col3" >['LHR', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7ab81_row1_col0" class="data row1 col0" >LHR</td>
#       <td id="T_7ab81_row1_col1" class="data row1 col1" >YPO</td>
#       <td id="T_7ab81_row1_col2" class="data row1 col2" >4150.000000</td>
#       <td id="T_7ab81_row1_col3" class="data row1 col3" >['LHR', 'DUB', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_7ab81_row2_col0" class="data row2 col0" >LHR</td>
#       <td id="T_7ab81_row2_col1" class="data row2 col1" >YPO</td>
#       <td id="T_7ab81_row2_col2" class="data row2 col2" >4164.000000</td>
#       <td id="T_7ab81_row2_col3" class="data row2 col3" >['LHR', 'YUL', 'YMT', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_7ab81_row3_col0" class="data row3 col0" >LHR</td>
#       <td id="T_7ab81_row3_col1" class="data row3 col1" >YPO</td>
#       <td id="T_7ab81_row3_col2" class="data row3 col2" >4167.000000</td>
#       <td id="T_7ab81_row3_col3" class="data row3 col3" >['LHR', 'DUB', 'YUL', 'YMT', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_7ab81_row4_col0" class="data row4 col0" >LHR</td>
#       <td id="T_7ab81_row4_col1" class="data row4 col1" >YPO</td>
#       <td id="T_7ab81_row4_col2" class="data row4 col2" >4187.000000</td>
#       <td id="T_7ab81_row4_col3" class="data row4 col3" >['LHR', 'MAN', 'DUB', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_7ab81_row5_col0" class="data row5 col0" >LHR</td>
#       <td id="T_7ab81_row5_col1" class="data row5 col1" >YPO</td>
#       <td id="T_7ab81_row5_col2" class="data row5 col2" >4202.000000</td>
#       <td id="T_7ab81_row5_col3" class="data row5 col3" >['LHR', 'IOM', 'DUB', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_7ab81_row6_col0" class="data row6 col0" >LHR</td>
#       <td id="T_7ab81_row6_col1" class="data row6 col1" >YPO</td>
#       <td id="T_7ab81_row6_col2" class="data row6 col2" >4204.000000</td>
#       <td id="T_7ab81_row6_col3" class="data row6 col3" >['LHR', 'MAN', 'DUB', 'YUL', 'YMT', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_7ab81_row7_col0" class="data row7 col0" >LHR</td>
#       <td id="T_7ab81_row7_col1" class="data row7 col1" >YPO</td>
#       <td id="T_7ab81_row7_col2" class="data row7 col2" >4209.000000</td>
#       <td id="T_7ab81_row7_col3" class="data row7 col3" >['LHR', 'YUL', 'YMT', 'YNS', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_7ab81_row8_col0" class="data row8 col0" >LHR</td>
#       <td id="T_7ab81_row8_col1" class="data row8 col1" >YPO</td>
#       <td id="T_7ab81_row8_col2" class="data row8 col2" >4211.000000</td>
#       <td id="T_7ab81_row8_col3" class="data row8 col3" >['LHR', 'MAN', 'IOM', 'DUB', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#     <tr>
#       <th id="T_7ab81_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_7ab81_row9_col0" class="data row9 col0" >LHR</td>
#       <td id="T_7ab81_row9_col1" class="data row9 col1" >YPO</td>
#       <td id="T_7ab81_row9_col2" class="data row9 col2" >4212.000000</td>
#       <td id="T_7ab81_row9_col3" class="data row9 col3" >['LHR', 'DUB', 'YUL', 'YMT', 'YNS', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# If efficiency is really important to you, you can use the A* algorithm with a good heuristic function:

# %%
code_lat_lon[code, lat, lon] := *airport{code, lat, lon}
starting[code, lat, lon] := code = 'LHR', *airport{code, lat, lon};
goal[code, lat, lon] := code = 'YPO', *airport{code, lat, lon};
?[] <~ ShortestPathAStar(*route[], 
                         code_lat_lon[node, lat1, lon1], 
                         starting[], 
                         goal[goal, lat2, lon2], 
                         heuristic: haversine_deg_input(lat1, lon1, lat2, lon2) * 3963);
# Out:
# <style type="text/css">
# #T_79b12_row0_col0, #T_79b12_row0_col1 {
#   color: black;
# }
# #T_79b12_row0_col2 {
#   color: #307fc1;
# }
# #T_79b12_row0_col3 {
#   color: #bf5b3d;
# }
# </style>
# <table id="T_79b12">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79b12_level0_col0" class="col_heading level0 col0" >_0</th>
#       <th id="T_79b12_level0_col1" class="col_heading level0 col1" >_1</th>
#       <th id="T_79b12_level0_col2" class="col_heading level0 col2" >_2</th>
#       <th id="T_79b12_level0_col3" class="col_heading level0 col3" >_3</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79b12_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_79b12_row0_col0" class="data row0 col0" >LHR</td>
#       <td id="T_79b12_row0_col1" class="data row0 col1" >YPO</td>
#       <td id="T_79b12_row0_col2" class="data row0 col2" >4147.000000</td>
#       <td id="T_79b12_row0_col3" class="data row0 col3" >['LHR', 'YUL', 'YVO', 'YKQ', 'YMO', 'YFA', 'ZKE', 'YAT', 'YPO']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# There's a lot more setup required in this case: we need to retrieve the latitudes and longitudes of airports and do processing on them first.
# The number `3963` above is the radius of the earth in miles.
#
# The most important airports, by PageRank:

# %%
rank[code, score] <~ PageRank(*route[a, b])
?[code, desc, score] := rank[code, score], *airport{code, desc}

:limit 10;
:order -score
# Out:
# <style type="text/css">
# #T_96755_row0_col0, #T_96755_row0_col1, #T_96755_row1_col0, #T_96755_row1_col1, #T_96755_row2_col0, #T_96755_row2_col1, #T_96755_row3_col0, #T_96755_row3_col1, #T_96755_row4_col0, #T_96755_row4_col1, #T_96755_row5_col0, #T_96755_row5_col1, #T_96755_row6_col0, #T_96755_row6_col1, #T_96755_row7_col0, #T_96755_row7_col1, #T_96755_row8_col0, #T_96755_row8_col1, #T_96755_row9_col0, #T_96755_row9_col1 {
#   color: black;
# }
# #T_96755_row0_col2, #T_96755_row1_col2, #T_96755_row2_col2, #T_96755_row3_col2, #T_96755_row4_col2, #T_96755_row5_col2, #T_96755_row6_col2, #T_96755_row7_col2, #T_96755_row8_col2, #T_96755_row9_col2 {
#   color: #307fc1;
# }
# </style>
# <table id="T_96755">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96755_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_96755_level0_col1" class="col_heading level0 col1" >desc</th>
#       <th id="T_96755_level0_col2" class="col_heading level0 col2" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96755_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96755_row0_col0" class="data row0 col0" >IST</td>
#       <td id="T_96755_row0_col1" class="data row0 col1" >Istanbul International Airport</td>
#       <td id="T_96755_row0_col2" class="data row0 col2" >0.004889</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96755_row1_col0" class="data row1 col0" >DFW</td>
#       <td id="T_96755_row1_col1" class="data row1 col1" >Dallas/Fort Worth International Airport</td>
#       <td id="T_96755_row1_col2" class="data row1 col2" >0.004696</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96755_row2_col0" class="data row2 col0" >ORD</td>
#       <td id="T_96755_row2_col1" class="data row2 col1" >Chicago O'Hare International Airport</td>
#       <td id="T_96755_row2_col2" class="data row2 col2" >0.004452</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96755_row3_col0" class="data row3 col0" >DEN</td>
#       <td id="T_96755_row3_col1" class="data row3 col1" >Denver International Airport</td>
#       <td id="T_96755_row3_col2" class="data row3 col2" >0.004252</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96755_row4_col0" class="data row4 col0" >PEK</td>
#       <td id="T_96755_row4_col1" class="data row4 col1" >Beijing Capital International Airport</td>
#       <td id="T_96755_row4_col2" class="data row4 col2" >0.004044</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_96755_row5_col0" class="data row5 col0" >FRA</td>
#       <td id="T_96755_row5_col1" class="data row5 col1" >Frankfurt am Main</td>
#       <td id="T_96755_row5_col2" class="data row5 col2" >0.004027</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_96755_row6_col0" class="data row6 col0" >ATL</td>
#       <td id="T_96755_row6_col1" class="data row6 col1" >Hartsfield - Jackson Atlanta International Airport</td>
#       <td id="T_96755_row6_col2" class="data row6 col2" >0.004022</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96755_row7_col0" class="data row7 col0" >DXB</td>
#       <td id="T_96755_row7_col1" class="data row7 col1" >Dubai International Airport</td>
#       <td id="T_96755_row7_col2" class="data row7 col2" >0.004002</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96755_row8_col0" class="data row8 col0" >CDG</td>
#       <td id="T_96755_row8_col1" class="data row8 col1" >Paris Charles de Gaulle</td>
#       <td id="T_96755_row8_col2" class="data row8 col2" >0.003998</td>
#     </tr>
#     <tr>
#       <th id="T_96755_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_96755_row9_col0" class="data row9 col0" >DME</td>
#       <td id="T_96755_row9_col1" class="data row9 col1" >Moscow, Domodedovo International Airport</td>
#       <td id="T_96755_row9_col2" class="data row9 col2" >0.003817</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The following example takes a long time to run since it calculates the betweenness centrality: up to a few seconds, depending on your machine.
# Algorithms for calculating the betweenness centrality have high complexity.

# %%
centrality[code, score] <~ BetweennessCentrality(*route[a, b])
?[code, desc, score] := centrality[code, score], *airport{code, desc}

:limit 10;
:order -score
# Out:
# <style type="text/css">
# #T_94a48_row0_col0, #T_94a48_row0_col1, #T_94a48_row1_col0, #T_94a48_row1_col1, #T_94a48_row2_col0, #T_94a48_row2_col1, #T_94a48_row3_col0, #T_94a48_row3_col1, #T_94a48_row4_col0, #T_94a48_row4_col1, #T_94a48_row5_col0, #T_94a48_row5_col1, #T_94a48_row6_col0, #T_94a48_row6_col1, #T_94a48_row7_col0, #T_94a48_row7_col1, #T_94a48_row8_col0, #T_94a48_row8_col1, #T_94a48_row9_col0, #T_94a48_row9_col1 {
#   color: black;
# }
# #T_94a48_row0_col2, #T_94a48_row1_col2, #T_94a48_row2_col2, #T_94a48_row3_col2, #T_94a48_row4_col2, #T_94a48_row5_col2, #T_94a48_row6_col2, #T_94a48_row7_col2, #T_94a48_row8_col2, #T_94a48_row9_col2 {
#   color: #307fc1;
# }
# </style>
# <table id="T_94a48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_94a48_level0_col0" class="col_heading level0 col0" >code</th>
#       <th id="T_94a48_level0_col1" class="col_heading level0 col1" >desc</th>
#       <th id="T_94a48_level0_col2" class="col_heading level0 col2" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_94a48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_94a48_row0_col0" class="data row0 col0" >ANC</td>
#       <td id="T_94a48_row0_col1" class="data row0 col1" >Anchorage Ted Stevens</td>
#       <td id="T_94a48_row0_col2" class="data row0 col2" >1074868.250000</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_94a48_row1_col0" class="data row1 col0" >KEF</td>
#       <td id="T_94a48_row1_col1" class="data row1 col1" >Reykjavik, Keflavik International Airport</td>
#       <td id="T_94a48_row1_col2" class="data row1 col2" >928450.437500</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_94a48_row2_col0" class="data row2 col0" >HEL</td>
#       <td id="T_94a48_row2_col1" class="data row2 col1" >Helsinki Ventaa</td>
#       <td id="T_94a48_row2_col2" class="data row2 col2" >581588.500000</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_94a48_row3_col0" class="data row3 col0" >PEK</td>
#       <td id="T_94a48_row3_col1" class="data row3 col1" >Beijing Capital International Airport</td>
#       <td id="T_94a48_row3_col2" class="data row3 col2" >532021.062500</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_94a48_row4_col0" class="data row4 col0" >DEL</td>
#       <td id="T_94a48_row4_col1" class="data row4 col1" >Indira Gandhi International Airport</td>
#       <td id="T_94a48_row4_col2" class="data row4 col2" >472979.968750</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_94a48_row5_col0" class="data row5 col0" >IST</td>
#       <td id="T_94a48_row5_col1" class="data row5 col1" >Istanbul International Airport</td>
#       <td id="T_94a48_row5_col2" class="data row5 col2" >457882.156250</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_94a48_row6_col0" class="data row6 col0" >PKC</td>
#       <td id="T_94a48_row6_col1" class="data row6 col1" >Yelizovo Airport</td>
#       <td id="T_94a48_row6_col2" class="data row6 col2" >408571.000000</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_94a48_row7_col0" class="data row7 col0" >MSP</td>
#       <td id="T_94a48_row7_col1" class="data row7 col1" >Minneapolis-St.Paul International Airport</td>
#       <td id="T_94a48_row7_col2" class="data row7 col2" >396433.250000</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_94a48_row8_col0" class="data row8 col0" >LAX</td>
#       <td id="T_94a48_row8_col1" class="data row8 col1" >Los Angeles International Airport</td>
#       <td id="T_94a48_row8_col2" class="data row8 col2" >393309.968750</td>
#     </tr>
#     <tr>
#       <th id="T_94a48_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_94a48_row9_col0" class="data row9 col0" >DEN</td>
#       <td id="T_94a48_row9_col1" class="data row9 col1" >Denver International Airport</td>
#       <td id="T_94a48_row9_col2" class="data row9 col2" >374339.531250</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# These are the airports that, if disconnected from the network, cause the most disruption.
# As this example shows, some of the algorithms really struggle when you go beyond small or medium sized dataset.
#
# Community detection can collapse a graph into a _supergraph_.
# Here we store the result, since it has too many rows to display nicely:

# %%
community[detailed_cluster, code] <~ CommunityDetectionLouvain(*route[a, b])
?[code, cluster, detailed_cluster] := community[detailed_cluster, code], cluster = first(detailed_cluster)

:replace community {code => cluster, detailed_cluster}
# Out:
# <style type="text/css">
# #T_73c2e_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_73c2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_73c2e_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_73c2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_73c2e_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We can look at the supernodes containing specific nodes. For example, the supernode for London Gatwick consists of mainly UK and other European airports, as you would expect:

# %%
community[code] := *community{code: 'LGW', cluster}, *community{code, cluster}
?[country, count(code)] := 
    community[code], 
    *airport{code, desc, country: country_code}, 
    *country{code: country_code, desc: country},

:order -count(code)
:limit 5
# Out:
# <style type="text/css">
# #T_4f66c_row0_col0, #T_4f66c_row1_col0, #T_4f66c_row2_col0, #T_4f66c_row3_col0, #T_4f66c_row4_col0 {
#   color: black;
# }
# #T_4f66c_row0_col1, #T_4f66c_row1_col1, #T_4f66c_row2_col1, #T_4f66c_row3_col1, #T_4f66c_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_4f66c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f66c_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_4f66c_level0_col1" class="col_heading level0 col1" >count(code)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f66c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f66c_row0_col0" class="data row0 col0" >United Kingdom</td>
#       <td id="T_4f66c_row0_col1" class="data row0 col1" >54</td>
#     </tr>
#     <tr>
#       <th id="T_4f66c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f66c_row1_col0" class="data row1 col0" >France</td>
#       <td id="T_4f66c_row1_col1" class="data row1 col1" >50</td>
#     </tr>
#     <tr>
#       <th id="T_4f66c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_4f66c_row2_col0" class="data row2 col0" >Norway</td>
#       <td id="T_4f66c_row2_col1" class="data row2 col1" >49</td>
#     </tr>
#     <tr>
#       <th id="T_4f66c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_4f66c_row3_col0" class="data row3 col0" >Spain</td>
#       <td id="T_4f66c_row3_col1" class="data row3 col1" >40</td>
#     </tr>
#     <tr>
#       <th id="T_4f66c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_4f66c_row4_col0" class="data row4 col0" >Greece</td>
#       <td id="T_4f66c_row4_col1" class="data row4 col1" >38</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# For `JFK` on the other hand, its supernode consists of mainly US airports:

# %%
community[code] := *community{code: 'JFK', cluster}, *community{code, cluster}
?[country, count(code)] := 
    community[code], 
    *airport{code, desc, country: country_code}, 
    *country{code: country_code, desc: country},

:order -count(code)
:limit 5
# Out:
# <style type="text/css">
# #T_1308e_row0_col0, #T_1308e_row1_col0, #T_1308e_row2_col0, #T_1308e_row3_col0, #T_1308e_row4_col0 {
#   color: black;
# }
# #T_1308e_row0_col1, #T_1308e_row1_col1, #T_1308e_row2_col1, #T_1308e_row3_col1, #T_1308e_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_1308e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1308e_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_1308e_level0_col1" class="col_heading level0 col1" >count(code)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1308e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1308e_row0_col0" class="data row0 col0" >United States</td>
#       <td id="T_1308e_row0_col1" class="data row0 col1" >444</td>
#     </tr>
#     <tr>
#       <th id="T_1308e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1308e_row1_col0" class="data row1 col0" >Canada</td>
#       <td id="T_1308e_row1_col1" class="data row1 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_1308e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1308e_row2_col0" class="data row2 col0" >Brazil</td>
#       <td id="T_1308e_row2_col1" class="data row2 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_1308e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1308e_row3_col0" class="data row3 col0" >Mexico</td>
#       <td id="T_1308e_row3_col1" class="data row3 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_1308e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1308e_row4_col0" class="data row4 col0" >Colombia</td>
#       <td id="T_1308e_row4_col1" class="data row4 col1" >50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# But it does not always work according to geography. For example, Frankfurt airport is in Germany:

# %%
?[desc, country_desc] := *airport{code: 'FRA', desc, country: country_code}, *country{code: country_code, desc: country_desc}
# Out:
# <style type="text/css">
# #T_fae58_row0_col0, #T_fae58_row0_col1 {
#   color: black;
# }
# </style>
# <table id="T_fae58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fae58_level0_col0" class="col_heading level0 col0" >desc</th>
#       <th id="T_fae58_level0_col1" class="col_heading level0 col1" >country_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fae58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fae58_row0_col0" class="data row0 col0" >Frankfurt am Main</td>
#       <td id="T_fae58_row0_col1" class="data row0 col1" >Germany</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# But its supernode:

# %%
community[code] := *community{code: 'FRA', cluster}, *community{code, cluster}
?[country, count(code)] := 
    community[code], 
    *airport{code, desc, country: country_code}, 
    *country{code: country_code, desc: country},

:order -count(code)
:limit 5
# Out:
# <style type="text/css">
# #T_2ef4d_row0_col0, #T_2ef4d_row1_col0, #T_2ef4d_row2_col0, #T_2ef4d_row3_col0, #T_2ef4d_row4_col0 {
#   color: black;
# }
# #T_2ef4d_row0_col1, #T_2ef4d_row1_col1, #T_2ef4d_row2_col1, #T_2ef4d_row3_col1, #T_2ef4d_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_2ef4d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2ef4d_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_2ef4d_level0_col1" class="col_heading level0 col1" >count(code)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2ef4d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2ef4d_row0_col0" class="data row0 col0" >United States</td>
#       <td id="T_2ef4d_row0_col1" class="data row0 col1" >444</td>
#     </tr>
#     <tr>
#       <th id="T_2ef4d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2ef4d_row1_col0" class="data row1 col0" >Canada</td>
#       <td id="T_2ef4d_row1_col1" class="data row1 col1" >111</td>
#     </tr>
#     <tr>
#       <th id="T_2ef4d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2ef4d_row2_col0" class="data row2 col0" >Brazil</td>
#       <td id="T_2ef4d_row2_col1" class="data row2 col1" >108</td>
#     </tr>
#     <tr>
#       <th id="T_2ef4d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2ef4d_row3_col0" class="data row3 col0" >Mexico</td>
#       <td id="T_2ef4d_row3_col1" class="data row3 col1" >57</td>
#     </tr>
#     <tr>
#       <th id="T_2ef4d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2ef4d_row4_col0" class="data row4 col0" >Colombia</td>
#       <td id="T_2ef4d_row4_col1" class="data row4 col1" >50</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Germany does not even appear in the top five. In fact, `FRA` is in the same supernode as `JFK`. What matters is the connectivity in the graph, not the geography.
# As another example:

# %%
community[code] := *community{code: 'SIN', cluster}, *community{code, cluster}
?[country, count(code)] := 
    community[code], 
    *airport{code, desc, country: country_code}, 
    *country{code: country_code, desc: country},

:order -count(code)
:limit 5
# Out:
# <style type="text/css">
# #T_37a77_row0_col0, #T_37a77_row1_col0, #T_37a77_row2_col0, #T_37a77_row3_col0, #T_37a77_row4_col0 {
#   color: black;
# }
# #T_37a77_row0_col1, #T_37a77_row1_col1, #T_37a77_row2_col1, #T_37a77_row3_col1, #T_37a77_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_37a77">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_37a77_level0_col0" class="col_heading level0 col0" >country</th>
#       <th id="T_37a77_level0_col1" class="col_heading level0 col1" >count(code)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_37a77_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_37a77_row0_col0" class="data row0 col0" >China</td>
#       <td id="T_37a77_row0_col1" class="data row0 col1" >216</td>
#     </tr>
#     <tr>
#       <th id="T_37a77_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_37a77_row1_col0" class="data row1 col0" >Australia</td>
#       <td id="T_37a77_row1_col1" class="data row1 col1" >125</td>
#     </tr>
#     <tr>
#       <th id="T_37a77_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_37a77_row2_col0" class="data row2 col0" >Indonesia</td>
#       <td id="T_37a77_row2_col1" class="data row2 col1" >68</td>
#     </tr>
#     <tr>
#       <th id="T_37a77_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_37a77_row3_col0" class="data row3 col0" >Japan</td>
#       <td id="T_37a77_row3_col1" class="data row3 col1" >65</td>
#     </tr>
#     <tr>
#       <th id="T_37a77_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_37a77_row4_col0" class="data row4 col0" >Philippines</td>
#       <td id="T_37a77_row4_col1" class="data row4 col1" >40</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You'd expect `SIN` to be a Chinese airport. Wrong:

# %%
?[desc, country_desc] := *airport{code: 'SIN', desc, country: country_code}, *country{code: country_code, desc: country_desc}
# Out:
# <style type="text/css">
# #T_49a21_row0_col0, #T_49a21_row0_col1 {
#   color: black;
# }
# </style>
# <table id="T_49a21">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49a21_level0_col0" class="col_heading level0 col0" >desc</th>
#       <th id="T_49a21_level0_col1" class="col_heading level0 col1" >country_desc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_49a21_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_49a21_row0_col0" class="data row0 col0" >Singapore, Changi International Airport</td>
#       <td id="T_49a21_row0_col1" class="data row0 col1" >Singapore</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finally, let's collapse the `route` relation into `super_route`:

# %%
?[fr_cluster, to_cluster, count(dist), sum(dist)] := *route{fr, to, dist}, 
                                                     *community{code: fr, cluster: fr_cluster},
                                                     *community{code: to, cluster: to_cluster}
:replace super_route {fr_cluster, to_cluster => n_routes=count(dist), total_distance=sum(dist)}
# Out:
# <style type="text/css">
# #T_367a5_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_367a5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_367a5_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_367a5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_367a5_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# As expected, the "diagonals" where `fr_cluster == to_cluster` are larger in the `super_route` graph:

# %%
?[fr_cluster, to_cluster, n_routes, total_distance] := *super_route{fr_cluster, to_cluster, n_routes, total_distance}, fr_cluster < 2
# Out:
# <style type="text/css">
# #T_d8165_row0_col0, #T_d8165_row0_col1, #T_d8165_row0_col2, #T_d8165_row0_col3, #T_d8165_row1_col0, #T_d8165_row1_col1, #T_d8165_row1_col2, #T_d8165_row1_col3, #T_d8165_row2_col0, #T_d8165_row2_col1, #T_d8165_row2_col2, #T_d8165_row2_col3, #T_d8165_row3_col0, #T_d8165_row3_col1, #T_d8165_row3_col2, #T_d8165_row3_col3, #T_d8165_row4_col0, #T_d8165_row4_col1, #T_d8165_row4_col2, #T_d8165_row4_col3, #T_d8165_row5_col0, #T_d8165_row5_col1, #T_d8165_row5_col2, #T_d8165_row5_col3, #T_d8165_row6_col0, #T_d8165_row6_col1, #T_d8165_row6_col2, #T_d8165_row6_col3, #T_d8165_row7_col0, #T_d8165_row7_col1, #T_d8165_row7_col2, #T_d8165_row7_col3, #T_d8165_row8_col0, #T_d8165_row8_col1, #T_d8165_row8_col2, #T_d8165_row8_col3, #T_d8165_row9_col0, #T_d8165_row9_col1, #T_d8165_row9_col2, #T_d8165_row9_col3, #T_d8165_row10_col0, #T_d8165_row10_col1, #T_d8165_row10_col2, #T_d8165_row10_col3, #T_d8165_row11_col0, #T_d8165_row11_col1, #T_d8165_row11_col2, #T_d8165_row11_col3, #T_d8165_row12_col0, #T_d8165_row12_col1, #T_d8165_row12_col2, #T_d8165_row12_col3, #T_d8165_row13_col0, #T_d8165_row13_col1, #T_d8165_row13_col2, #T_d8165_row13_col3, #T_d8165_row14_col0, #T_d8165_row14_col1, #T_d8165_row14_col2, #T_d8165_row14_col3, #T_d8165_row15_col0, #T_d8165_row15_col1, #T_d8165_row15_col2, #T_d8165_row15_col3 {
#   color: #307fc1;
# }
# </style>
# <table id="T_d8165">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d8165_level0_col0" class="col_heading level0 col0" >fr_cluster</th>
#       <th id="T_d8165_level0_col1" class="col_heading level0 col1" >to_cluster</th>
#       <th id="T_d8165_level0_col2" class="col_heading level0 col2" >n_routes</th>
#       <th id="T_d8165_level0_col3" class="col_heading level0 col3" >total_distance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d8165_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d8165_row0_col0" class="data row0 col0" >0</td>
#       <td id="T_d8165_row0_col1" class="data row0 col1" >0</td>
#       <td id="T_d8165_row0_col2" class="data row0 col2" >9041</td>
#       <td id="T_d8165_row0_col3" class="data row0 col3" >8933554.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d8165_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_d8165_row1_col1" class="data row1 col1" >1</td>
#       <td id="T_d8165_row1_col2" class="data row1 col2" >434</td>
#       <td id="T_d8165_row1_col3" class="data row1 col3" >1695379.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d8165_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_d8165_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_d8165_row2_col2" class="data row2 col2" >228</td>
#       <td id="T_d8165_row2_col3" class="data row2 col3" >761661.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d8165_row3_col0" class="data row3 col0" >0</td>
#       <td id="T_d8165_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_d8165_row3_col2" class="data row3 col2" >530</td>
#       <td id="T_d8165_row3_col3" class="data row3 col3" >1681865.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d8165_row4_col0" class="data row4 col0" >0</td>
#       <td id="T_d8165_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_d8165_row4_col2" class="data row4 col2" >163</td>
#       <td id="T_d8165_row4_col3" class="data row4 col3" >391892.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d8165_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_d8165_row5_col1" class="data row5 col1" >8</td>
#       <td id="T_d8165_row5_col2" class="data row5 col2" >3</td>
#       <td id="T_d8165_row5_col3" class="data row5 col3" >300.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d8165_row6_col0" class="data row6 col0" >0</td>
#       <td id="T_d8165_row6_col1" class="data row6 col1" >11</td>
#       <td id="T_d8165_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_d8165_row6_col3" class="data row6 col3" >283.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d8165_row7_col0" class="data row7 col0" >0</td>
#       <td id="T_d8165_row7_col1" class="data row7 col1" >19</td>
#       <td id="T_d8165_row7_col2" class="data row7 col2" >1</td>
#       <td id="T_d8165_row7_col3" class="data row7 col3" >238.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d8165_row8_col0" class="data row8 col0" >0</td>
#       <td id="T_d8165_row8_col1" class="data row8 col1" >21</td>
#       <td id="T_d8165_row8_col2" class="data row8 col2" >2</td>
#       <td id="T_d8165_row8_col3" class="data row8 col3" >705.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d8165_row9_col0" class="data row9 col0" >0</td>
#       <td id="T_d8165_row9_col1" class="data row9 col1" >22</td>
#       <td id="T_d8165_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_d8165_row9_col3" class="data row9 col3" >975.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d8165_row10_col0" class="data row10 col0" >1</td>
#       <td id="T_d8165_row10_col1" class="data row10 col1" >0</td>
#       <td id="T_d8165_row10_col2" class="data row10 col2" >434</td>
#       <td id="T_d8165_row10_col3" class="data row10 col3" >1696858.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d8165_row11_col0" class="data row11 col0" >1</td>
#       <td id="T_d8165_row11_col1" class="data row11 col1" >1</td>
#       <td id="T_d8165_row11_col2" class="data row11 col2" >4474</td>
#       <td id="T_d8165_row11_col3" class="data row11 col3" >5142452.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d8165_row12_col0" class="data row12 col0" >1</td>
#       <td id="T_d8165_row12_col1" class="data row12 col1" >2</td>
#       <td id="T_d8165_row12_col2" class="data row12 col2" >1160</td>
#       <td id="T_d8165_row12_col3" class="data row12 col3" >1492734.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d8165_row13_col0" class="data row13 col0" >1</td>
#       <td id="T_d8165_row13_col1" class="data row13 col1" >3</td>
#       <td id="T_d8165_row13_col2" class="data row13 col2" >526</td>
#       <td id="T_d8165_row13_col3" class="data row13 col3" >1724591.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d8165_row14_col0" class="data row14 col0" >1</td>
#       <td id="T_d8165_row14_col1" class="data row14 col1" >4</td>
#       <td id="T_d8165_row14_col2" class="data row14 col2" >223</td>
#       <td id="T_d8165_row14_col3" class="data row14 col3" >361986.000000</td>
#     </tr>
#     <tr>
#       <th id="T_d8165_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d8165_row15_col0" class="data row15 col0" >1</td>
#       <td id="T_d8165_row15_col1" class="data row15 col1" >9</td>
#       <td id="T_d8165_row15_col2" class="data row15 col2" >1</td>
#       <td id="T_d8165_row15_col3" class="data row15 col3" >808.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Now the super graph is small enough that all analytics algorithms return instantly:

# %%
?[cluster, score] <~ PageRank(*super_route[])
:order -score
:limit 5
# Out:
# <style type="text/css">
# #T_5322d_row0_col0, #T_5322d_row0_col1, #T_5322d_row1_col0, #T_5322d_row1_col1, #T_5322d_row2_col0, #T_5322d_row2_col1, #T_5322d_row3_col0, #T_5322d_row3_col1, #T_5322d_row4_col0, #T_5322d_row4_col1 {
#   color: #307fc1;
# }
# </style>
# <table id="T_5322d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5322d_level0_col0" class="col_heading level0 col0" >cluster</th>
#       <th id="T_5322d_level0_col1" class="col_heading level0 col1" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5322d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5322d_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_5322d_row0_col1" class="data row0 col1" >0.173309</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_5322d_row1_col0" class="data row1 col0" >0</td>
#       <td id="T_5322d_row1_col1" class="data row1 col1" >0.093072</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_5322d_row2_col0" class="data row2 col0" >1</td>
#       <td id="T_5322d_row2_col1" class="data row2 col1" >0.053465</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_5322d_row3_col0" class="data row3 col0" >2</td>
#       <td id="T_5322d_row3_col1" class="data row3 col1" >0.053389</td>
#     </tr>
#     <tr>
#       <th id="T_5322d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_5322d_row4_col0" class="data row4 col0" >4</td>
#       <td id="T_5322d_row4_col1" class="data row4 col1" >0.044654</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# You can now go on to investigate the supernodes, give real-world interpretations to them, etc.
# For example, a naïve interpretation of the above PageRank result is that
# North America is (still) the most prosperous part of the world,
# followed by East Asia in the second place, South Asia in the third place, and Europe in the fourth place.

# %% [markdown]
# ## Importing dataset the hard way
#
# Previously, we imported the air-routes dataset by using Python under the hood to download a specially-crafted JSON file and feed it to the database.
# Here we learn how to achieve the same effect by letting Cozo fetch and import a series of CSV files, without Python's help.
#
# Let's set the database magic up first:

# %%
::access_level normal airport, contain, continent, country, route
# Out:
# <style type="text/css">
# #T_ecee8_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_ecee8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ecee8_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ecee8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ecee8_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %%
::remove airport, contain, continent, country, route, community, super_route
# Out:
# <style type="text/css">
# #T_482e8_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_482e8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_482e8_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_482e8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_482e8_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Next, some parameters to make life eaiser (the lines commented out do the same thing by processing local files):

# %%
# %cozo_set AIR_ROUTES_NODES_URL 'https://raw.githubusercontent.com/cozodb/cozo/dev/cozo-core/tests/air-routes-latest-nodes.csv'
# %cozo_set AIR_ROUTES_EDGES_URL 'https://raw.githubusercontent.com/cozodb/cozo/dev/cozo-core/tests/air-routes-latest-edges.csv'
# %cozo_set AIR_ROUTES_NODES_URL 'file://./../../cozo/cozo-core/tests/air-routes-latest-nodes.csv'
# %cozo_set AIR_ROUTES_EDGES_URL 'file://./../../cozo/cozo-core/tests/air-routes-latest-edges.csv'

# %% [markdown]
# First, import the `airport` relation:

# %%
res[idx, label, typ, code, icao, desc, region, runways, longest, elev, country, city, lat, lon] <~
    CsvReader(types: ['Int', 'Any', 'Any', 'Any', 'Any', 'Any', 'Any', 'Int?', 'Float?', 'Float?', 'Any', 'Any', 'Float?', 'Float?'],
              url: $AIR_ROUTES_NODES_URL, 
              has_headers: true)

?[code, icao, desc, region, runways, longest, elev, country, city, lat, lon] :=
    res[idx, label, typ, code, icao, desc, region, runways, longest, elev, country, city, lat, lon],
    label == 'airport'

:replace airport {
    code: String 
    => 
    icao: String, 
    desc: String, 
    region: String, 
    runways: Int, 
    longest: Float, 
    elev: Float, 
    country: String, 
    city: String, 
    lat: Float, 
    lon: Float
}
# Out:
# <style type="text/css">
# #T_f3c91_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_f3c91">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f3c91_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f3c91_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f3c91_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `CsvReader` utility downloads a CSV file from the internet and attempts to parse its content into a relation.
# When we store the relation, we specified types for the columns. The `code` column acts as a primary key for the `airport` stored relation.
#
# Next is `country`:

# %%
res[idx, label, typ, code, icao, desc] <~
    CsvReader(types: ['Int', 'Any', 'Any', 'Any', 'Any', 'Any'],
              url: $AIR_ROUTES_NODES_URL, 
              has_headers: true)
?[code, desc] :=
    res[idx, label, typ, code, icao, desc],
    label == 'country'

:replace country {
    code: String
    =>
    desc: String
}
# Out:
# <style type="text/css">
# #T_57c45_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_57c45">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_57c45_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_57c45_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_57c45_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# `continent`:

# %%
res[idx, label, typ, code, icao, desc] <~
    CsvReader(types: ['Int', 'Any', 'Any', 'Any', 'Any', 'Any'],
              url: $AIR_ROUTES_NODES_URL, 
              has_headers: true)
?[idx, code, desc] :=
    res[idx, label, typ, code, icao, desc],
    label == 'continent'

:replace continent {
    code: String
    =>
    desc: String
}
# Out:
# <style type="text/css">
# #T_cd3cd_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_cd3cd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cd3cd_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd3cd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd3cd_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We need to make a translation table for the indices the data use:

# %%
res[idx, label, typ, code] <~
    CsvReader(types: ['Int', 'Any', 'Any', 'Any'],
              url: $AIR_ROUTES_NODES_URL, 
              has_headers: true)
?[idx, code] :=
    res[idx, label, typ, code],

:replace idx2code { idx => code }
# Out:
# <style type="text/css">
# #T_a4c56_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_a4c56">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a4c56_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a4c56_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a4c56_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# The `contain` relation contains information on the geographical inclusion of entities:

# %%
res[] <~
    CsvReader(types: ['Int', 'Int', 'Int', 'String'],
              url: $AIR_ROUTES_EDGES_URL, 
              has_headers: true)
?[entity, contained] :=
    res[idx, fr_i, to_i, typ],
    typ == 'contains',
    *idx2code[fr_i, entity],
    *idx2code[to_i, contained]


:replace contain { entity: String, contained: String }
# Out:
# <style type="text/css">
# #T_3c9a6_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_3c9a6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c9a6_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c9a6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c9a6_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Finally, the `route`s between the airports. This relation is much larger than the rest and contains about 60k rows:

# %%
res[] <~
    CsvReader(types: ['Int', 'Int', 'Int', 'String', 'Float?'],
              url: $AIR_ROUTES_EDGES_URL, 
              has_headers: true)
?[fr, to, dist] :=
    res[idx, fr_i, to_i, typ, dist],
    typ == 'route',
    *idx2code[fr_i, fr],
    *idx2code[to_i, to]

:replace route { fr: String, to: String => dist: Float }
# Out:
# <style type="text/css">
# #T_feb95_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_feb95">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_feb95_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_feb95_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_feb95_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# We no longer need the `idx2code` relation:

# %%
::remove idx2code
# Out:
# <style type="text/css">
# #T_ed6dd_row0_col0 {
#   color: black;
# }
# </style>
# <table id="T_ed6dd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed6dd_level0_col0" class="col_heading level0 col0" >status</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed6dd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ed6dd_row0_col0" class="data row0 col0" >OK</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Let's verify all the relations we want are there:

# %%
::relations
# Out:
# <style type="text/css">
# #T_c622a_row0_col0, #T_c622a_row0_col2, #T_c622a_row0_col8, #T_c622a_row1_col0, #T_c622a_row1_col2, #T_c622a_row1_col8, #T_c622a_row2_col0, #T_c622a_row2_col2, #T_c622a_row2_col8, #T_c622a_row3_col0, #T_c622a_row3_col2, #T_c622a_row3_col8, #T_c622a_row4_col0, #T_c622a_row4_col2, #T_c622a_row4_col8, #T_c622a_row5_col0, #T_c622a_row5_col2, #T_c622a_row5_col8, #T_c622a_row6_col0, #T_c622a_row6_col2, #T_c622a_row6_col8, #T_c622a_row7_col0, #T_c622a_row7_col2, #T_c622a_row7_col8 {
#   color: black;
# }
# #T_c622a_row0_col1, #T_c622a_row0_col3, #T_c622a_row0_col4, #T_c622a_row0_col5, #T_c622a_row0_col6, #T_c622a_row0_col7, #T_c622a_row1_col1, #T_c622a_row1_col3, #T_c622a_row1_col4, #T_c622a_row1_col5, #T_c622a_row1_col6, #T_c622a_row1_col7, #T_c622a_row2_col1, #T_c622a_row2_col3, #T_c622a_row2_col4, #T_c622a_row2_col5, #T_c622a_row2_col6, #T_c622a_row2_col7, #T_c622a_row3_col1, #T_c622a_row3_col3, #T_c622a_row3_col4, #T_c622a_row3_col5, #T_c622a_row3_col6, #T_c622a_row3_col7, #T_c622a_row4_col1, #T_c622a_row4_col3, #T_c622a_row4_col4, #T_c622a_row4_col5, #T_c622a_row4_col6, #T_c622a_row4_col7, #T_c622a_row5_col1, #T_c622a_row5_col3, #T_c622a_row5_col4, #T_c622a_row5_col5, #T_c622a_row5_col6, #T_c622a_row5_col7, #T_c622a_row6_col1, #T_c622a_row6_col3, #T_c622a_row6_col4, #T_c622a_row6_col5, #T_c622a_row6_col6, #T_c622a_row6_col7, #T_c622a_row7_col1, #T_c622a_row7_col3, #T_c622a_row7_col4, #T_c622a_row7_col5, #T_c622a_row7_col6, #T_c622a_row7_col7 {
#   color: #307fc1;
# }
# </style>
# <table id="T_c622a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c622a_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_c622a_level0_col1" class="col_heading level0 col1" >arity</th>
#       <th id="T_c622a_level0_col2" class="col_heading level0 col2" >access_level</th>
#       <th id="T_c622a_level0_col3" class="col_heading level0 col3" >n_keys</th>
#       <th id="T_c622a_level0_col4" class="col_heading level0 col4" >n_non_keys</th>
#       <th id="T_c622a_level0_col5" class="col_heading level0 col5" >n_put_triggers</th>
#       <th id="T_c622a_level0_col6" class="col_heading level0 col6" >n_rm_triggers</th>
#       <th id="T_c622a_level0_col7" class="col_heading level0 col7" >n_replace_triggers</th>
#       <th id="T_c622a_level0_col8" class="col_heading level0 col8" >description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c622a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c622a_row0_col0" class="data row0 col0" >airport</td>
#       <td id="T_c622a_row0_col1" class="data row0 col1" >11</td>
#       <td id="T_c622a_row0_col2" class="data row0 col2" >normal</td>
#       <td id="T_c622a_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_c622a_row0_col4" class="data row0 col4" >10</td>
#       <td id="T_c622a_row0_col5" class="data row0 col5" >0</td>
#       <td id="T_c622a_row0_col6" class="data row0 col6" >0</td>
#       <td id="T_c622a_row0_col7" class="data row0 col7" >0</td>
#       <td id="T_c622a_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c622a_row1_col0" class="data row1 col0" >contain</td>
#       <td id="T_c622a_row1_col1" class="data row1 col1" >2</td>
#       <td id="T_c622a_row1_col2" class="data row1 col2" >normal</td>
#       <td id="T_c622a_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_c622a_row1_col4" class="data row1 col4" >0</td>
#       <td id="T_c622a_row1_col5" class="data row1 col5" >0</td>
#       <td id="T_c622a_row1_col6" class="data row1 col6" >0</td>
#       <td id="T_c622a_row1_col7" class="data row1 col7" >0</td>
#       <td id="T_c622a_row1_col8" class="data row1 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c622a_row2_col0" class="data row2 col0" >continent</td>
#       <td id="T_c622a_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_c622a_row2_col2" class="data row2 col2" >normal</td>
#       <td id="T_c622a_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_c622a_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_c622a_row2_col5" class="data row2 col5" >0</td>
#       <td id="T_c622a_row2_col6" class="data row2 col6" >0</td>
#       <td id="T_c622a_row2_col7" class="data row2 col7" >0</td>
#       <td id="T_c622a_row2_col8" class="data row2 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c622a_row3_col0" class="data row3 col0" >country</td>
#       <td id="T_c622a_row3_col1" class="data row3 col1" >2</td>
#       <td id="T_c622a_row3_col2" class="data row3 col2" >normal</td>
#       <td id="T_c622a_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_c622a_row3_col4" class="data row3 col4" >1</td>
#       <td id="T_c622a_row3_col5" class="data row3 col5" >0</td>
#       <td id="T_c622a_row3_col6" class="data row3 col6" >0</td>
#       <td id="T_c622a_row3_col7" class="data row3 col7" >0</td>
#       <td id="T_c622a_row3_col8" class="data row3 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c622a_row4_col0" class="data row4 col0" >dept_info</td>
#       <td id="T_c622a_row4_col1" class="data row4 col1" >4</td>
#       <td id="T_c622a_row4_col2" class="data row4 col2" >normal</td>
#       <td id="T_c622a_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_c622a_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_c622a_row4_col5" class="data row4 col5" >0</td>
#       <td id="T_c622a_row4_col6" class="data row4 col6" >0</td>
#       <td id="T_c622a_row4_col7" class="data row4 col7" >0</td>
#       <td id="T_c622a_row4_col8" class="data row4 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_c622a_row5_col0" class="data row5 col0" >route</td>
#       <td id="T_c622a_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_c622a_row5_col2" class="data row5 col2" >normal</td>
#       <td id="T_c622a_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_c622a_row5_col4" class="data row5 col4" >1</td>
#       <td id="T_c622a_row5_col5" class="data row5 col5" >0</td>
#       <td id="T_c622a_row5_col6" class="data row5 col6" >0</td>
#       <td id="T_c622a_row5_col7" class="data row5 col7" >0</td>
#       <td id="T_c622a_row5_col8" class="data row5 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_c622a_row6_col0" class="data row6 col0" >test</td>
#       <td id="T_c622a_row6_col1" class="data row6 col1" >1</td>
#       <td id="T_c622a_row6_col2" class="data row6 col2" >normal</td>
#       <td id="T_c622a_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_c622a_row6_col4" class="data row6 col4" >0</td>
#       <td id="T_c622a_row6_col5" class="data row6 col5" >0</td>
#       <td id="T_c622a_row6_col6" class="data row6 col6" >0</td>
#       <td id="T_c622a_row6_col7" class="data row6 col7" >0</td>
#       <td id="T_c622a_row6_col8" class="data row6 col8" ></td>
#     </tr>
#     <tr>
#       <th id="T_c622a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_c622a_row7_col0" class="data row7 col0" >test2</td>
#       <td id="T_c622a_row7_col1" class="data row7 col1" >1</td>
#       <td id="T_c622a_row7_col2" class="data row7 col2" >normal</td>
#       <td id="T_c622a_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_c622a_row7_col4" class="data row7 col4" >0</td>
#       <td id="T_c622a_row7_col5" class="data row7 col5" >0</td>
#       <td id="T_c622a_row7_col6" class="data row7 col6" >0</td>
#       <td id="T_c622a_row7_col7" class="data row7 col7" >0</td>
#       <td id="T_c622a_row7_col8" class="data row7 col8" ></td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# That's it for the tutorial!
